# %%
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
import sys

# %%
with open("/Volumes/Drive/GitHub/DaVinciCodeTheTrackOfRobertLangdon/models/roberta-results", "rb") as fp:   # Unpickling
# with open("C:/Users/Admin/Documents/University/CurrentClass/IRTM/DaVinciCodeTheTrackOfRobertLangdon/models/roberta-results", "rb") as fp:
    bert_tags = pickle.load(fp)

# %%
bert_tags
# Out:
# [(' The Da Vinci Code', 'MISC', 1),
#  (' Dan Brown', 'PER', 1),
#  (' Louvre Museum', 'LOC', 1),
#  (' Paris', 'LOC', 1),
#  (' Jacques Sauniere', 'PER', 1),
#  (' Grand Gallery', 'LOC', 1),
#  (' Caravaggio', 'PER', 2),
#  (' Sauniere', 'PER', 3),
#  (' albino', 'MISC', 16),
#  (' Sauniere', 'PER', 31),
#  (' Sauniere', 'PER', 33),
#  (' Sauniere', 'PER', 44),
#  (' Sauniere', 'PER', 51),
#  (' senechaux', 'PER', 51),
#  (' Sauniere', 'PER', 64),
#  (' Sauniere', 'PER', 65),
#  (' Sauniere', 'PER', 66),
#  (' Sauniere', 'PER', 70),
#  (" Guerre d'Algerie", 'MISC', 76),
#  ('.', 'MISC', 76),
#  (' Jacques Sauniere', 'PER', 80),
#  (' Jacques Sauniere', 'PER', 97),
#  (' Grand Gallery', 'LOC', 103),
#  (' Sauniere', 'PER', 104),
#  (' Robert Langdon', 'PER', 108),
#  (' Renaissance', 'MISC', 111),
#  (' Louis XVI', 'MISC', 111),
#  (' HOTEL RITZ PARIS', 'LOC', 113),
#  (' Langdon', 'PER', 114),
#  (' Langdon', 'PER', 116),
#  (' Langdon', 'PER', 119),
#  (' Langdon', 'PER', 124),
#  (' AMERICAN UNIVERSITY OF PARIS', 'ORG', 127),
#  (' ROBERT LANGDON', 'PER', 127),
#  (' HARVARD UNIVERSITY', 'ORG', 127),
#  (' Langdon', 'PER', 127),
#  (' Chartres Cathedral', 'LOC', 128),
#  (' Langdon', 'PER', 130),
#  (' Langdon', 'PER', 132),
#  (' Langdon', 'PER', 133),
#  (' Vatican', 'LOC', 133),
#  (' Langdon', 'PER', 135),
#  (' Paris', 'LOC', 135),
#  (' Langdon', 'PER', 138),
#  (' Guest Relations Handbook', 'MISC', 138),
#  (' CITY OF LIGHTS', 'LOC', 138),
#  (' PARIS RITZ', 'LOC', 138),
#  (' Robert', 'PER', 140),
#  (' Langdon', 'PER', 145),
#  ('Boston Magazine', 'ORG', 146),
#  (' Langdon', 'PER', 147),
#  (' Boston Magazine', 'ORG', 147),
#  (' Harvard', 'ORG', 147),
#  (' American University of Paris', 'ORG', 152),
#  (' Pavilion Dauphine', 'LOC', 152),
#  (' The Symbology of Secret Sects', 'MISC', 153),
#  (' The An of the Illuminati', 'MISC', 153),
#  (' The Lost Language of Ideograms', 'MISC', 153),
#  (' Langdon', 'PER', 160),
#  (' Boston Magazine', 'ORG', 165),
#  (' Langdon', 'PER', 166),
#  (' Langdon', 'PER', 168),
#  (' Langdon', 'PER', 170),
#  (' Vatican', 'LOC', 170),
#  (' Langdon', 'PER', 174),
#  (' Langdon', 'PER', 175),
#  (' Langdon', 'PER', 178),
#  ('Harrison Ford', 'PER', 179),
#  (' Harris', 'ORG', 179),
#  (' Harris', 'ORG', 179),
#  (' Burberry', 'ORG', 179),
#  (' Monique', 'PER', 180),
#  (' Langdon', 'PER', 180),
#  ('Boston Magazine', 'ORG', 181),
#  (' Langdon', 'PER', 188),
#  (' Langdon', 'PER', 192),
#  (' Langdon', 'PER', 195),
#  (' Langdon', 'PER', 203),
#  (' Langdon', 'PER', 204),
#  (' Langdon', 'PER', 207),
#  (' English', 'MISC', 209),
#  (' Jerome Collet', 'PER', 210),
#  (' Direction Centrale Police Judiciaire.', 'ORG', 211),
#  (' Langdon', 'PER', 212),
#  (' Judicial Police', 'ORG', 213),
#  (' DCPJ', 'ORG', 214),
#  (' U', 'ORG', 214),
#  ('S. FBI.', 'ORG', 214),
#  (' Langdon', 'PER', 214),
#  ('.', 'ORG', 214),
#  (' Langdon', 'PER', 219),
#  (' Langdon', 'PER', 223),
#  (' Louvre', 'LOC', 225),
#  (' Langdon', 'PER', 226),
#  (' Jacques Sauniere', 'PER', 227),
#  (' Langdon', 'PER', 227),
#  (' Sauniere', 'PER', 227),
#  (' Polaroid', 'MISC', 232),
#  (' Langdon', 'PER', 233),
#  (' Louvre', 'LOC', 235),
#  (' Langdon', 'PER', 236),
#  (' Langdon', 'PER', 239),
#  (' Langdon', 'PER', 241),
#  (' Vatican City', 'LOC', 242),
#  (' Langdon', 'PER', 246),
#  (' Langdon', 'PER', 253),
#  (' Langdon', 'PER', 256),
#  (' Sauniere', 'PER', 261),
#  ('bino', 'MISC', 262),
#  (' Silas', 'PER', 262),
#  (' Rue La Bruyere', 'LOC', 262),
#  (' New York City', 'LOC', 271),
#  (' Silas', 'PER', 273),
#  (' senechaux', 'PER', 280),
#  (' Silas', 'PER', 295),
#  (' keystone', 'LOC', 299),
#  (' Paris', 'LOC', 312),
#  ('Paris', 'LOC', 313),
#  (' Silas', 'PER', 316),
#  (' Silas', 'PER', 320),
#  (' Paris', 'LOC', 320),
#  (' Eglise de Saint- Sulpice', 'LOC', 320),
#  (' God', 'PER', 326),
#  (' Silas', 'PER', 332),
#  (' Teacher', 'PER', 332),
#  (' Silas', 'PER', 337),
#  (' God', 'PER', 338),
#  (' God', 'PER', 341),
#  (' Silas', 'PER', 343),
#  (' The Way', 'MISC', 346),
#  (' Christ', 'PER', 346),
#  (' Silas', 'PER', 348),
#  (' Silas', 'PER', 351),
#  (' Josemaria Escriva', 'PER', 351),
#  (' Teacher', 'PER', 351),
#  (' Escriva', 'PER', 352),
#  (' Silas', 'PER', 353),
#  (' The Discipline', 'ORG', 354),
#  (' Silas', 'PER', 356),
#  (' Castigo corpus meum', 'ORG', 360),
#  (' Citroen ZX', 'MISC', 362),
#  (' Opera House', 'LOC', 362),
#  (' Place Vendome', 'LOC', 362),
#  (' Robert Langdon', 'PER', 363),
#  (' Jacques Sauniere', 'PER', 366),
#  (' Langdon', 'PER', 367),
#  (' Sauniere', 'PER', 368),
#  (' Poussin', 'PER', 369),
#  (' Teniers', 'PER', 369),
#  (' Langdon', 'PER', 369),
#  (' Langdon', 'PER', 370),
#  (' Jacques Sauniere', 'PER', 372),
#  (' Langdon', 'PER', 373),
#  (' Citroen', 'ORG', 375),
#  (' Paris', 'LOC', 376),
#  (' Langdon', 'PER', 378),
#  (' Langdon', 'PER', 379),
#  (' Harvard', 'ORG', 380),
#  (' Langdon', 'PER', 381),
#  (' American University of Paris', 'ORG', 381),
#  ('Interpol', 'ORG', 383),
#  (' Interpol', 'ORG', 384),
#  (' Langdon', 'PER', 384),
#  (' European', 'MISC', 386),
#  (' Europe', 'LOC', 387),
#  (' Interpol', 'ORG', 387),
#  (' Langdon', 'PER', 388),
#  (' Ritz', 'LOC', 388),
#  (' Citroen', 'ORG', 389),
#  (' Eiffel Tower', 'LOC', 389),
#  (' Langdon', 'PER', 390),
#  (' Vittoria', 'PER', 390),
#  (' Eiffel Tower', 'LOC', 391),
#  (' Langdon', 'PER', 391),
#  (' Vittoria', 'PER', 392),
#  (' Rome', 'LOC', 392),
#  (' Langdon', 'PER', 395),
#  (' Eiffel Tower', 'LOC', 398),
#  (' Langdon', 'PER', 400),
#  (' France', 'LOC', 402),
#  (' Langdon', 'PER', 404),
#  (' France', 'LOC', 405),
#  (' Napoleon', 'PER', 405),
#  (' Pepin the Short', 'PER', 405),
#  (' Rue de Rivoli', 'LOC', 406),
#  (' Citroen', 'ORG', 406),
#  (' Rue Castiglione', 'LOC', 407),
#  (' Tuileries Gardens', 'LOC', 407),
#  (' Paris', 'LOC', 407),
#  (' Central Park', 'LOC', 407),
#  (' Jardins des Tuileries', 'LOC', 408),
#  (' Tuileries', 'LOC', 408),
#  (' Parisian', 'MISC', 409),
#  (' Langdon', 'PER', 411),
#  (' Langdon', 'PER', 413),
#  (' Tuileries', 'LOC', 413),
#  (' Claude Monet', 'PER', 414),
#  (' Impressionist', 'MISC', 414),
#  (' Citroen', 'ORG', 416),
#  (' Langdon', 'PER', 418),
#  (' Tuileries Gardens', 'LOC', 418),
#  (' Arc du Carrousel', 'MISC', 419),
#  (' Arc du Carrousel', 'LOC', 420),
#  (' Tuileries', 'LOC', 421),
#  (' Seine', 'LOC', 425),
#  (' Quai Voltaire', 'LOC', 425),
#  (' Langdon', 'PER', 425),
#  (" Musee d'Orsay", 'LOC', 425),
#  (' Pompidou Center', 'LOC', 426),
#  (' Museum of Modern Art', 'ORG', 426),
#  (' Langdon', 'PER', 427),
#  (' Ramses', 'LOC', 427),
#  (' Musee du Jeu de Paume', 'LOC', 427),
#  (' Langdon', 'PER', 428),
#  (' Renaissance', 'MISC', 428),
#  (' Musee du Louvre', 'LOC', 429),
#  (' Langdon', 'PER', 430),
#  (' Louvre', 'LOC', 431),
#  (' Paris', 'LOC', 431),
#  (' Louvre', 'LOC', 432),
#  (' Europe', 'LOC', 432),
#  (' Eiffel Towers', 'LOC', 432),
#  (' Langdon', 'PER', 434),
#  (' Louvre', 'LOC', 434),
#  (' Langdon', 'PER', 435),
#  ('Louvre', 'LOC', 435),
#  (' Lite', 'MISC', 435),
#  (' Mona Lisa', 'MISC', 435),
#  (' Venus de Milo', 'MISC', 435),
#  (' Winged Victory', 'MISC', 435),
#  (' Art Buchwald', 'PER', 436),
#  (' French', 'MISC', 437),
#  (' Langdon', 'PER', 438),
#  (' Langdon', 'PER', 441),
#  (' Citroen', 'ORG', 443),
#  (' Louvre', 'LOC', 444),
#  (' La Pyramide', 'ORG', 445),
#  (' Paris Louvre', 'LOC', 446),
#  ('omod', 'MISC', 447),
#  (' Chinese-born American', 'MISC', 447),
#  (' I. M. Pei', 'PER', 447),
#  (' Renaissance', 'MISC', 447),
#  ('.', 'PER', 447),
#  (' Goethe', 'PER', 448),
#  (' Pei', 'PER', 448),
#  (' Pei', 'PER', 449),
#  (' Louvre', 'LOC', 449),
#  (' Langdon', 'PER', 452),
#  (' French', 'MISC', 453),
#  (' Americans', 'MISC', 453),
#  (' American', 'MISC', 455),
#  (' French', 'MISC', 455),
#  ('Mitterrand', 'PER', 456),
#  (' Langdon', 'PER', 456),
#  (' French', 'MISC', 457),
#  ('Pharaoh', 'PER', 457),
#  (' Paris', 'LOC', 458),
#  (' Egyptian', 'MISC', 458),
#  (' Francois Mitterrand', 'PER', 459),
#  (' Egyptian', 'MISC', 459),
#  (' French', 'MISC', 459),
#  (' Sphinx', 'PER', 459),
#  (' Langdon', 'PER', 461),
#  ('Bezu', 'ORG', 462),
#  (' F', 'LOC', 462),
#  ('ache', 'ORG', 462),
#  (' le Taureau', 'PER', 463),
#  (' Langdon', 'PER', 464),
#  (' Frenchman', 'MISC', 464),
#  (' Bull', 'PER', 465),
#  (' French', 'MISC', 467),
#  (' Langdon', 'PER', 467),
#  (' French', 'MISC', 468),
#  (' Langdon', 'PER', 468),
#  (' Taurus', 'ORG', 469),
#  (' Langdon', 'PER', 477),
#  (' Langdon', 'PER', 480),
#  (' Langdon', 'PER', 482),
#  (' Sphinx', 'PER', 485),
#  (' Bull', 'PER', 485),
#  (' Salvador Dali', 'PER', 486),
#  (' Langdon', 'PER', 487),
#  (' Langdon', 'PER', 490),
#  (' Harvard', 'ORG', 490),
#  (' Egyptologists', 'MISC', 490),
#  (' Neanderthal', 'MISC', 492),
#  (' Langdon', 'PER', 495),
#  (' Bezu Fache', 'PER', 496),
#  (' Langdon', 'PER', 496),
#  (' Central Directorate Judicial Police', 'ORG', 497),
#  (' Langdon', 'PER', 502),
#  ('Robert Langdon', 'PER', 503),
#  (' Fache', 'PER', 504),
#  (' Langdon', 'PER', 504),
#  (' Langdon', 'PER', 505),
#  (' Jacques Sauniere', 'PER', 506),
#  (' Langdon', 'PER', 506),
#  (' Fache', 'PER', 506),
#  (' Sauniere', 'PER', 507),
#  (' Bezu Fache', 'PER', 508),
#  (' Langdon', 'PER', 511),
#  (' Judicial Police', 'ORG', 512),
#  (' Fache', 'PER', 513),
#  (' Langdon', 'PER', 514),
#  (' Fache', 'PER', 515),
#  (' Louvre', 'LOC', 515),
#  (' Langdon', 'PER', 517),
#  (' Fache', 'PER', 520),
#  (' Langdon', 'PER', 521),
#  (' Fache', 'PER', 523),
#  (' Paris', 'LOC', 524),
#  (' Langdon', 'PER', 526),
#  (' Fache', 'PER', 527),
#  (' Mitterrand', 'PER', 527),
#  (' Satan', 'PER', 527),
#  (' Langdon', 'PER', 528),
#  (' Louvre', 'LOC', 530),
#  (' Louvre', 'LOC', 531),
#  (' Langdon', 'PER', 534),
#  (' Fache', 'PER', 535),
#  (' Langdon', 'PER', 535),
#  (' Fache', 'PER', 535),
#  (' Louvre', 'LOC', 537),
#  (' Sully Wing', 'LOC', 537),
#  (' Langdon', 'PER', 539),
#  (' Fache', 'PER', 539),
#  (' Jacques Sauniere', 'PER', 540),
#  (' Fache', 'PER', 544),
#  (' American University', 'ORG', 547),
#  (' Fache', 'PER', 548),
#  (' Langdon', 'PER', 549),
#  (' Louvre', 'LOC', 549),
#  (' La Pyramide Inversee', 'LOC', 549),
#  (' entresol', 'LOC', 549),
#  (' Fache', 'PER', 550),
#  (' Langdon', 'PER', 550),
#  (' DENON', 'LOC', 550),
#  (' Denon Wing', 'LOC', 550),
#  (' Louvre', 'LOC', 550),
#  (' Fache', 'PER', 552),
#  (' Sauniere', 'PER', 555),
#  (' Langdon', 'PER', 555),
#  (' Paris', 'LOC', 557),
#  (' Fache', 'PER', 562),
#  (' Langdon', 'PER', 564),
#  (' Jacques Sauniere', 'PER', 566),
#  (' Langdon', 'PER', 566),
#  (' Langdon', 'PER', 567),
#  (' Langdon', 'PER', 569),
#  (' Sauniere', 'PER', 573),
#  (' Fache', 'PER', 575),
#  (' Denon Wing', 'LOC', 576),
#  (' Langdon', 'PER', 576),
#  (' Fache', 'PER', 578),
#  (' Sauniere', 'PER', 580),
#  (' Fache', 'PER', 582),
#  (' Langdon', 'PER', 588),
#  (' Fache', 'PER', 590),
#  (' Sauniere', 'PER', 591),
#  (' Langdon', 'PER', 594),
#  (' Fache', 'PER', 594),
#  (' Jacques Sauniere', 'PER', 595),
#  (' Sauniere', 'PER', 596),
#  (' Wicca', 'MISC', 596),
#  (' Sauniere', 'PER', 596),
#  (' Louvre', 'LOC', 596),
#  (' Greek', 'MISC', 596),
#  (' Delphi', 'LOC', 596),
#  (' Tjet', 'MISC', 596),
#  (' Egypt', 'LOC', 596),
#  (' Horus', 'PER', 596),
#  (' Isis', 'PER', 596),
#  (' Jacques Sauniere', 'PER', 597),
#  (' Fache', 'PER', 598),
#  (' Langdon', 'PER', 600),
#  (' Fache', 'PER', 603),
#  (' Langdon', 'PER', 604),
#  (' Symbols of the Lost Sacred Feminine', 'MISC', 605),
#  (' Langdon', 'PER', 606),
#  (' Fache', 'PER', 606),
#  (' Langdon', 'PER', 607),
#  (' Fache', 'PER', 607),
#  (' Fache', 'PER', 608),
#  (' Langdon', 'PER', 610),
#  (' Denon Wing', 'LOC', 610),
#  (' Fache', 'PER', 612),
#  (' Langdon', 'PER', 613),
#  (' Langdon', 'PER', 615),
#  (' Langdon', 'PER', 617),
#  (' Sauniere', 'PER', 622),
#  (' Fache', 'PER', 622),
#  (' Langdon', 'PER', 626),
#  (' Fache', 'PER', 628),
#  (' Langdon', 'PER', 630),
#  (' Langdon', 'PER', 632),
#  (' Christian', 'MISC', 633),
#  (' Christ', 'PER', 633),
#  (' Langdon', 'PER', 634),
#  (' French', 'MISC', 634),
#  (' France', 'LOC', 635),
#  (' Christianity', 'MISC', 635),
#  (' Fache', 'PER', 636),
#  (' Langdon', 'PER', 637),
#  (' Fache', 'PER', 637),
#  (' Langdon', 'PER', 639),
#  (' Louvre', 'LOC', 639),
#  (' Langdon', 'PER', 641),
#  (' Fache', 'PER', 642),
#  (' Langdon', 'PER', 643),
#  (' Louvre', 'LOC', 643),
#  (' Langdon', 'PER', 644),
#  (' Louvre', 'LOC', 645),
#  (' Langdon', 'PER', 647),
#  (' Fache', 'PER', 651),
#  (' Langdon', 'PER', 652),
#  (' Langdon', 'PER', 661),
#  (' Fache', 'PER', 662),
#  (' Langdon', 'PER', 664),
#  (' Louvre', 'LOC', 666),
#  (' Fache', 'PER', 675),
#  (' Langdon', 'PER', 675),
#  (' Sauniere', 'PER', 675),
#  (' Old Master', 'MISC', 675),
#  (' Sauniere', 'PER', 677),
#  (' DCPJ', 'ORG', 678),
#  (' Fache', 'PER', 679),
#  (' Entendu', 'PER', 681),
#  (' Langdon', 'PER', 683),
#  (' NE P', 'MISC', 683),
#  ('AS', 'ORG', 683),
#  (' DERANG', 'MISC', 683),
#  ('ER', 'ORG', 683),
#  (' Fache', 'PER', 684),
#  (' Langdon', 'PER', 684),
#  (' Fache', 'PER', 685),
#  (' Langdon', 'PER', 685),
#  (' Louvre', 'LOC', 686),
#  (' la Grande Galerie', 'LOC', 686),
#  (' Louvre', 'LOC', 686),
#  (' Italian', 'MISC', 686),
#  (' Langdon', 'PER', 687),
#  (' Sauniere', 'PER', 687),
#  (' Grand Gallery', 'LOC', 687),
#  (' Polaroid', 'MISC', 687),
#  (' Langdon', 'PER', 688),
#  (' Fache', 'PER', 689),
#  (' Langdon', 'PER', 691),
#  (' Grand Gallery', 'LOC', 691),
#  (' Langdon', 'PER', 692),
#  (' Fache', 'PER', 692),
#  (' Langdon', 'PER', 693),
#  (' Fache', 'PER', 695),
#  (' Langdon', 'PER', 696),
#  (' Louvre', 'LOC', 699),
#  (' Fache', 'PER', 699),
#  (' Police Technique et Scientifique', 'ORG', 700),
#  (' Langdon', 'PER', 703),
#  (' Fache', 'PER', 706),
#  (' French', 'MISC', 706),
#  (' Langdon', 'PER', 708),
#  (' Langdon', 'PER', 709),
#  (' Harris', 'ORG', 711),
#  (' Robert', 'PER', 712),
#  (' Langdon', 'PER', 713),
#  (' Murray Hill Place', 'LOC', 714),
#  (' Opus Dei World Headquarters', 'ORG', 714),
#  (' Lexington Avenue', 'LOC', 714),
#  (' New York City', 'LOC', 714),
#  (' Indiana', 'LOC', 715),
#  (' May & Pinska', 'ORG', 716),
#  (' Lexington Avenue', 'LOC', 719),
#  (' Manuel Aringarosa', 'PER', 721),
#  (' Rome', 'LOC', 725),
#  (' Aringarosa', 'PER', 725),
#  (' Atlantic', 'LOC', 725),
#  (' Aringarosa', 'PER', 726),
#  (' Opus Dei', 'ORG', 728),
#  (' Aringarosa', 'PER', 728),
#  ('God', 'PER', 728),
#  ("'s Work", 'MISC', 728),
#  (' Opus Dei', 'ORG', 728),
#  (' Spanish', 'MISC', 729),
#  (' Josemaria Escriva', 'PER', 729),
#  (' Catholic', 'MISC', 729),
#  (' God', 'PER', 729),
#  (' Opus Dei', 'ORG', 730),
#  (' Spain', 'LOC', 730),
#  (' Franco', 'PER', 730),
#  (' Josemaria Escriva', 'PER', 730),
#  (' The Way', 'MISC', 730),
#  (' God', 'PER', 730),
#  (' Escriva', 'PER', 730),
#  (' The Way', 'MISC', 731),
#  (' Opus Dei', 'ORG', 731),
#  (' Opus Dei', 'ORG', 733),
#  (' Catholic', 'MISC', 733),
#  (' Aringarosa', 'PER', 734),
#  (' Opus Dei', 'ORG', 734),
#  (' Opus Dei', 'ORG', 735),
#  (' Christian', 'MISC', 736),
#  ('Opus Dei', 'ORG', 738),
#  (' Catholic', 'MISC', 739),
#  (' Catholics', 'MISC', 740),
#  (' Catholic', 'MISC', 740),
#  (' God', 'PER', 741),
#  (' Opus Dei', 'ORG', 742),
#  (' Aringarosa', 'PER', 742),
#  (' Opus Dei', 'ORG', 744),
#  (' God', 'PER', 744),
#  (' Opus Dei', 'ORG', 746),
#  (' Work', 'MISC', 746),
#  (' God', 'PER', 746),
#  (' Opus Dei', 'ORG', 749),
#  (' Opus Dei', 'ORG', 750),
#  (' midwestern', 'MISC', 750),
#  (' Boston', 'LOC', 752),
#  (' Opus Dei', 'ORG', 752),
#  (' Aringarosa', 'PER', 753),
#  (' FBI', 'ORG', 754),
#  (' Robert Hanssen', 'PER', 754),
#  (' Opus Dei', 'ORG', 754),
#  (' Catholic', 'MISC', 755),
#  (' Opus Dei Awareness Network', 'ORG', 756),
#  ('ODAN', 'ORG', 756),
#  (' odan.', 'ORG', 758),
#  (' Opus Dei', 'ORG', 759),
#  (' Opus Dei', 'ORG', 760),
#  ('God', 'PER', 760),
#  (' Mafia', 'ORG', 760),
#  (' Cult of Christ', 'ORG', 760),
#  (' Aringarosa', 'PER', 761),
#  (' Opus Dei', 'ORG', 761),
#  (' Vatican', 'LOC', 762),
#  (' Opus Dei', 'ORG', 763),
#  (' Opus Dei', 'ORG', 764),
#  (' Aringarosa', 'PER', 767),
#  (' Aringar', 'PER', 768),
#  ('osa', 'ORG', 768),
#  (' Aringarosa', 'PER', 769),
#  (' Spain', 'LOC', 770),
#  (' Aringarosa', 'PER', 772),
#  (' Portugal', 'LOC', 773),
#  (' Aringarosa', 'PER', 773),
#  (' Aringarosa', 'PER', 774),
#  (' Aringarosa', 'PER', 775),
#  ('Silas', 'PER', 778),
#  (' Paris', 'LOC', 779),
#  (' Church of Saint-Sulpice.', 'LOC', 780),
#  (' Aringarosa', 'PER', 781),
#  (' Aringarosa', 'PER', 787),
#  (' Silas', 'PER', 789),
#  (' Psalms', 'MISC', 790),
#  (' Silas', 'PER', 792),
#  (' The Way', 'MISC', 794),
#  (' Jesus', 'PER', 806),
#  (' Silas', 'PER', 813),
#  (' Christ', 'PER', 814),
#  (' God', 'PER', 815),
#  (' Christian', 'MISC', 817),
#  (' Silas', 'PER', 818),
#  (' Robert Langdon', 'PER', 823),
#  (' Grand Gallery', 'LOC', 823),
#  (' Da Vincis', 'PER', 826),
#  (' Titians', 'MISC', 826),
#  (' Caravaggios', 'MISC', 826),
#  (' Grand Gallery', 'LOC', 828),
#  (' Louvre', 'LOC', 828),
#  (' Italian', 'MISC', 828),
#  (' Langdon', 'PER', 830),
#  (' Fache', 'PER', 831),
#  (' Caravaggio', 'PER', 835),
#  (' Fache', 'PER', 836),
#  (' Langdon', 'PER', 837),
#  (' Fache', 'PER', 839),
#  (' Langdon', 'PER', 840),
#  (' Langdon', 'PER', 844),
#  (' Grand Gallery', 'LOC', 845),
#  (' Langdon', 'PER', 848),
#  (' Grand Gallery', 'LOC', 849),
#  (' Fache', 'PER', 850),
#  (' Sauniere', 'PER', 851),
#  (' Sauniere', 'PER', 852),
#  (' Fache', 'PER', 853),
#  (' PTS', 'ORG', 854),
#  (' Sauniere', 'PER', 856),
#  (' Langdon', 'PER', 857),
#  (' Sauniere', 'PER', 857),
#  (' Langdon', 'PER', 859),
#  (' Fache', 'PER', 861),
#  (' Grand Gallery', 'LOC', 862),
#  (' Langdon', 'PER', 863),
#  (' Washington Monuments', 'LOC', 863),
#  (' Fache', 'PER', 866),
#  (' Langdon', 'PER', 867),
#  (' Langdon', 'PER', 869),
#  (' Vatican Secret Archives', 'LOC', 869),
#  (' Rome', 'LOC', 870),
#  (' Vittoria', 'PER', 871),
#  (' Langdon', 'PER', 873),
#  (' Rome', 'LOC', 873),
#  (' Vittoria', 'PER', 875),
#  (' Java Sea', 'LOC', 875),
#  (' Langdon', 'PER', 879),
#  (' Vittoria Vetra', 'PER', 879),
#  (' Rome', 'LOC', 879),
#  (' Langdon', 'PER', 884),
#  ('Jacques Sauniere', 'PER', 885),
#  (' Sauniere', 'PER', 886),
#  (' Langdon', 'PER', 890),
#  (' Louvre', 'LOC', 893),
#  (' Grand Gallery', 'LOC', 893),
#  (' Judicial Police', 'ORG', 896),
#  (' Langdon', 'PER', 907),
#  (' Fache', 'PER', 907),
#  (' Fache', 'PER', 908),
#  (' Langdon', 'PER', 909),
#  (' Fache', 'PER', 912),
#  (' Langdon', 'PER', 913),
#  (' Jacques Sauniere', 'PER', 915),
#  (' Langdon', 'PER', 916),
#  (' Sauniere', 'PER', 916),
#  (' Sauniere', 'PER', 917),
#  (' Sauniere', 'PER', 926),
#  (' Sauniere', 'PER', 928),
#  (' Sauniere', 'PER', 928),
#  (' Sauniere', 'PER', 930),
#  (' Langdon', 'PER', 931),
#  (' Langdon', 'PER', 931),
#  (' Langdon', 'PER', 933),
#  (' Fache', 'PER', 934),
#  (' Langdon', 'PER', 935),
#  (' Christ', 'PER', 937),
#  (' Langdon', 'PER', 939),
#  (' Ku Klux Klan', 'ORG', 941),
#  (' United States', 'LOC', 941),
#  (' Spain', 'LOC', 941),
#  (' Langdon', 'PER', 942),
#  (' Fache', 'PER', 944),
#  (' Langdon', 'PER', 946),
#  (' pagan', 'MISC', 947),
#  (' Latin paganus', 'MISC', 948),
#  ('Pagans', 'MISC', 949),
#  (' Langdon', 'PER', 951),
#  (' pre-Christian', 'MISC', 951),
#  (' Langdon', 'PER', 957),
#  (' Sauniere', 'PER', 957),
#  (' Sauniere', 'PER', 959),
#  ('Sauniere', 'PER', 960),
#  (' Langdon', 'PER', 961),
#  (' Venus', 'PER', 962),
#  (' Fache', 'PER', 963),
#  (' Nature', 'MISC', 964),
#  (' Venus', 'PER', 965),
#  (' Venus', 'LOC', 965),
#  (' Venus', 'PER', 966),
#  (' Eastern Star', 'PER', 966),
#  (' Ishtar', 'PER', 966),
#  (' Astarte', 'PER', 966),
#  (' Earth', 'LOC', 966),
#  (' Fache', 'PER', 967),
#  (' Langdon', 'PER', 968),
#  (' Venus', 'LOC', 968),
#  (' Langdon', 'PER', 969),
#  (' Venus', 'LOC', 969),
#  (' ecliptic', 'MISC', 969),
#  (' Venus', 'PER', 970),
#  (' Venus', 'PER', 971),
#  (' Greeks', 'MISC', 971),
#  (' Olympiads', 'MISC', 971),
#  (' Olympic Games', 'MISC', 972),
#  (' Venus', 'LOC', 972),
#  (' Olympic', 'MISC', 973),
#  (' Langdon', 'PER', 974),
#  (' Fache', 'PER', 974),
#  (' American', 'MISC', 976),
#  (' Langdon', 'PER', 977),
#  (' Hollywood', 'LOC', 978),
#  (' Satanic', 'MISC', 979),
#  (' Satan', 'MISC', 979),
#  (' Langdon', 'PER', 980),
#  (' Langdon', 'PER', 981),
#  (' Langdon', 'PER', 985),
#  (' Fache', 'PER', 985),
#  (' Church', 'LOC', 986),
#  (' Roman Catholic', 'MISC', 987),
#  (' Church', 'ORG', 987),
#  (' Vatican', 'LOC', 988),
#  (' Christianity', 'MISC', 988),
#  (' Church', 'ORG', 988),
#  ('Goon', 'PER', 989),
#  (' Langdon', 'PER', 990),
#  (' Christian', 'MISC', 992),
#  (' Poseidon', 'PER', 992),
#  (' Venus', 'PER', 992),
#  (' Langdon', 'PER', 993),
#  (' United States', 'LOC', 994),
#  ('.', 'LOC', 994),
#  (' Fache', 'PER', 998),
#  (' Langdon', 'PER', 1001),
#  (' Fache', 'PER', 1003),
#  (' Jacques Sauniere', 'PER', 1007),
#  (' Fache', 'PER', 1009),
#  (' Sauniere', 'PER', 1009),
#  (' Langdon', 'PER', 1015),
#  (' Polaroid', 'MISC', 1016),
#  (' Venus', 'PER', 1017),
#  (' Venus', 'LOC', 1018),
#  (' Venus', 'LOC', 1018),
#  (' Langdon', 'PER', 1019),
#  (' Fache', 'PER', 1020),
#  (' Sauniere', 'PER', 1020),
#  (' Jacques Sauniere', 'PER', 1020),
#  (' Fache', 'PER', 1025),
#  (' Langdon', 'PER', 1029),
#  ('Sauniere', 'PER', 1031),
#  (' Fache', 'PER', 1031),
#  (' Langdon', 'LOC', 1031),
#  (' Langdon', 'PER', 1034),
#  (' STYLO DE LUMIERE NOIRE', 'ORG', 1035),
#  (' Langdon', 'PER', 1039),
#  (' Fache', 'PER', 1039),
#  (' Langdon', 'PER', 1041),
#  (' Fache', 'PER', 1042),
#  (' Fache', 'PER', 1044),
#  (' Langdon', 'PER', 1049),
#  (' Langdon', 'PER', 1052),
#  (' Langdon', 'PER', 1053),
#  (' Fache', 'PER', 1053),
#  (' Fache', 'PER', 1055),
#  (' Sauniere', 'PER', 1057),
#  (' Collet', 'PER', 1057),
#  (' Louvre', 'LOC', 1057),
#  (' Sauniere', 'PER', 1058),
#  (' Collet', 'PER', 1058),
#  (' AKG', 'ORG', 1059),
#  (' Grand Gallery', 'LOC', 1063),
#  (' Church of Saint-Sulpice', 'LOC', 1064),
#  (' Sandrine Bieil', 'PER', 1065),
#  (' Sandrine', 'PER', 1067),
#  ('Soeur Sandrine', 'PER', 1070),
#  (' Eglise Saint-Sulpice.', 'LOC', 1071),
#  (' French', 'MISC', 1072),
#  (' Sandrine', 'PER', 1073),
#  (' American', 'MISC', 1079),
#  (' Manuel Aringarosa', 'PER', 1081),
#  (' Opus Dei', 'ORG', 1082),
#  (' Aringarosa', 'PER', 1085),
#  (' Pope John Paul II', 'PER', 1086),
#  (' Opus Dei', 'ORG', 1087),
#  (' Vatican', 'LOC', 1087),
#  (' Institute for Religious Works', 'ORG', 1087),
#  (' Vatican Bank', 'ORG', 1087),
#  (' Pope', 'PER', 1088),
#  (' Opus Dei', 'ORG', 1088),
#  (' Sandrine', 'PER', 1089),
#  (' Opus Dei', 'ORG', 1089),
#  (' Rome', 'LOC', 1089),
#  (' Holy See', 'LOC', 1089),
#  (' Aringarosa', 'PER', 1090),
#  (' Paris', 'LOC', 1091),
#  (' Sandrine', 'PER', 1095),
#  (' Opus Dei', 'ORG', 1096),
#  (' Saint-Sulpice', 'LOC', 1099),
#  (' Saint-Sulpice', 'LOC', 1101),
#  (' Sandrine', 'PER', 1108),
#  (' Sandrine', 'PER', 1112),
#  (' Opus Dei', 'ORG', 1114),
#  ('.', 'ORG', 1114),
#  (' Eve', 'PER', 1120),
#  (' Catholic', 'MISC', 1121),
#  (' Church', 'ORG', 1121),
#  (' Opus Dei', 'ORG', 1121),
#  (' Sandrine', 'PER', 1122),
#  (' God', 'PER', 1126),
#  (' Sandrine', 'PER', 1126),
#  (' Langdon', 'PER', 1128),
#  (' Jacques Sauniere', 'PER', 1129),
#  (' Langdon', 'PER', 1129),
#  (' Draconian', 'MISC', 1130),
#  (' Langdon', 'PER', 1132),
#  (' Fache', 'PER', 1132),
#  (' Draconian', 'MISC', 1133),
#  (' Sauniere', 'PER', 1134),
#  (' Fache', 'PER', 1137),
#  (' Langdon', 'PER', 1142),
#  (' Sauniere', 'PER', 1143),
#  (' Langdon', 'PER', 1144),
#  (' Fache', 'PER', 1146),
#  (' Sauniere', 'PER', 1146),
#  (' Langdon', 'PER', 1151),
#  (' Langdon', 'PER', 1152),
#  (' Draconian', 'MISC', 1153),
#  (' Fache', 'PER', 1155),
#  (' Langdon', 'PER', 1157),
#  (' Grand Gallery', 'LOC', 1157),
#  (' Langdon', 'PER', 1161),
#  ('Draconian', 'MISC', 1166),
#  (' Langdon', 'PER', 1168),
#  (' Draco', 'PER', 1168),
#  (' B.C.', 'LOC', 1168),
#  ('.', 'LOC', 1168),
#  ('Draconian', 'MISC', 1169),
#  ('Draconian', 'MISC', 1170),
#  (' Fache', 'PER', 1171),
#  ('Sauniere', 'PER', 1172),
#  (' Langdon', 'PER', 1173),
#  (' Fache', 'PER', 1173),
#  (' Draco', 'PER', 1173),
#  (' Fache', 'PER', 1173),
#  ('Sauniere', 'PER', 1174),
#  (' Frenchman', 'MISC', 1174),
#  (' Fache', 'PER', 1174),
#  (' Paris', 'LOC', 1175),
#  (' English', 'MISC', 1179),
#  (' Langdon', 'PER', 1179),
#  (' Fache', 'PER', 1180),
#  (' Langdon', 'PER', 1183),
#  (' Sauniere', 'PER', 1183),
#  (' English', 'MISC', 1183),
#  (' English', 'MISC', 1183),
#  (' Langdon', 'PER', 1183),
#  (' Fache', 'PER', 1185),
#  (' Sauniere', 'PER', 1185),
#  (' Langdon', 'PER', 1188),
#  (' Fache', 'PER', 1192),
#  (' Langdon', 'PER', 1194),
#  (' Sauniere', 'PER', 1195),
#  (' Vitruvian Man', 'MISC', 1197),
#  (' Langdon', 'PER', 1197),
#  (' Sauniere', 'PER', 1198),
#  (' Leonardo da Vinci', 'PER', 1198),
#  (' Da Vinci', 'PER', 1199),
#  (' The Vitruvian Man', 'MISC', 1199),
#  (' Da Vinci', 'PER', 1204),
#  (' Langdon', 'PER', 1205),
#  (' Sauniere', 'PER', 1206),
#  (' Leonardo da Vinci', 'PER', 1207),
#  (' Vitruvian Man', 'MISC', 1207),
#  (' Da Vinci', 'PER', 1209),
#  (' Sauniere', 'PER', 1210),
#  (' Langdon', 'PER', 1211),
#  (' Fache', 'PER', 1211),
#  (' Leonardo da Vinci', 'PER', 1211),
#  (' Langdon', 'PER', 1212),
#  (' Fache', 'PER', 1212),
#  (' Da Vinci', 'PER', 1212),
#  (' Da Vinci', 'PER', 1213),
#  (' Christian', 'MISC', 1213),
#  (' God', 'PER', 1214),
#  (' Da Vinci', 'PER', 1215),
#  (' God', 'PER', 1215),
#  (' Langdon', 'PER', 1216),
#  (' Da Vinci', 'PER', 1217),
#  (' Christian', 'MISC', 1217),
#  (' Vatican', 'LOC', 1218),
#  (' Da Vinci', 'PER', 1218),
#  (' Christian', 'MISC', 1218),
#  (' Da Vinci', 'PER', 1219),
#  (' Christian', 'MISC', 1220),
#  (' Christian', 'MISC', 1220),
#  (' Langdon', 'PER', 1221),
#  (' National Gallery', 'LOC', 1221),
#  (' London', 'LOC', 1221),
#  (' Leonardo', 'PER', 1221),
#  (' Christian', 'MISC', 1221),
#  (' Langdon', 'PER', 1222),
#  (' Da Vinci', 'PER', 1222),
#  (' Langdon', 'PER', 1224),
#  (' O', 'MISC', 1226),
#  (' Draconian', 'MISC', 1226),
#  (' Fache', 'PER', 1229),
#  (' Langdon', 'PER', 1230),
#  (' Sauniere', 'PER', 1231),
#  (' Da Vinci', 'PER', 1231),
#  (' Church', 'ORG', 1231),
#  (' Da Vinci', 'PER', 1232),
#  (' Sauniere', 'PER', 1232),
#  (' Church', 'ORG', 1232),
#  (' Fache', 'PER', 1233),
#  (' Sauniere', 'PER', 1234),
#  (' Draconian', 'MISC', 1234),
#  (' Langdon', 'PER', 1235),
#  (' Sauniere', 'PER', 1236),
#  (' Catholic Church', 'ORG', 1236),
#  (' Sauniere', 'PER', 1237),
#  (' Fache', 'PER', 1239),
#  (' Langdon', 'PER', 1241),
#  (' Sauniere', 'PER', 1242),
#  (' Fache', 'PER', 1244),
#  (' Langdon', 'PER', 1245),
#  (' Fache', 'PER', 1248),
#  (' Sauniere', 'PER', 1250),
#  (' Langdon', 'PER', 1251),
#  (' Sauniere', 'PER', 1255),
#  (' Fache', 'PER', 1258),
#  (' Sauniere', 'PER', 1260),
#  (' Draconian', 'MISC', 1264),
#  (' Fache', 'PER', 1267),
#  (' Langdon', 'PER', 1269),
#  (' Sauniere', 'PER', 1269),
#  (' Langdon', 'PER', 1270),
#  (' Fache', 'PER', 1270),
#  (' Fache', 'PER', 1271),
#  (' Collet', 'PER', 1273),
#  (' Fache', 'PER', 1273),
#  (' French', 'MISC', 1274),
#  (' Fache', 'PER', 1275),
#  (' Fache', 'PER', 1277),
#  (' Fache', 'PER', 1279),
#  (' Fache', 'PER', 1280),
#  (' Jacques Sauniere', 'PER', 1281),
#  (' Fache', 'PER', 1281),
#  (' Collet', 'PER', 1285),
#  (' Fache', 'PER', 1285),
#  (' Bull', 'PER', 1285),
#  (' Fache', 'PER', 1286),
#  (' God', 'PER', 1287),
#  (' Fache', 'PER', 1287),
#  (' Collet', 'PER', 1288),
#  (' God', 'PER', 1288),
#  (' Bezu Fache', 'PER', 1288),
#  (' Pope', 'PER', 1290),
#  (' Paris', 'LOC', 1290),
#  (' Fache', 'PER', 1290),
#  (' Fache', 'PER', 1291),
#  (' Pope', 'PER', 1291),
#  (' Papal Bull', 'MISC', 1292),
#  (' Collet', 'PER', 1293),
#  (' Fache', 'PER', 1293),
#  (' Catholic', 'MISC', 1293),
#  (' Fache', 'PER', 1295),
#  (' Catholic', 'MISC', 1297),
#  (' Church', 'ORG', 1297),
#  (' Collet', 'PER', 1298),
#  (' Fache', 'PER', 1298),
#  (' Collet', 'PER', 1299),
#  (' GPS', 'MISC', 1299),
#  (' Denon Wing', 'LOC', 1300),
#  (' Louvre Security Office', 'ORG', 1300),
#  (' Collet', 'PER', 1301),
#  (' Grand Gallery', 'LOC', 1302),
#  (' La marque', 'ORG', 1303),
#  (' Fache', 'PER', 1304),
#  (' Robert Langdon', 'PER', 1306),
#  (' Langdon', 'PER', 1307),
#  (' Bezu Fache', 'PER', 1307),
#  ('Capitaine', 'LOC', 1309),
#  (' Fache', 'PER', 1311),
#  (' Collet', 'PER', 1312),
#  (' Langdon', 'PER', 1313),
#  (' Departement de Cryptographic', 'ORG', 1317),
#  (' Fache', 'PER', 1318),
#  (' Fache', 'PER', 1321),
#  (' Sauniere', 'PER', 1321),
#  (' Cryptography Department', 'ORG', 1321),
#  (' Sauniere', 'PER', 1321),
#  (' Sauniere', 'PER', 1322),
#  (' Fache', 'PER', 1323),
#  (' Neveu', 'PER', 1327),
#  (' Fache', 'PER', 1328),
#  (' Sophie Neveu', 'PER', 1329),
#  (' DCPJ', 'ORG', 1329),
#  (' Parisian', 'MISC', 1330),
#  (' England', 'LOC', 1330),
#  (' Royal Holloway', 'LOC', 1330),
#  (' Sophie Neveu', 'PER', 1330),
#  (' Fache', 'PER', 1330),
#  (' Fache', 'PER', 1331),
#  (' Fache', 'PER', 1333),
#  (' Sophie Neveu', 'PER', 1333),
#  (' Britain', 'LOC', 1335),
#  (' French', 'MISC', 1335),
#  (' Fache', 'PER', 1336),
#  (' Neveu', 'PER', 1337),
#  (' Fache', 'PER', 1339),
#  (' Robert Langdon', 'PER', 1341),
#  (' Bezu Fache', 'PER', 1341),
#  (' Langdon', 'PER', 1343),
#  (' Langdon', 'PER', 1344),
#  (' Langdon', 'PER', 1346),
#  (' Irish', 'MISC', 1351),
#  (' Harvard', 'ORG', 1353),
#  (' Langdon', 'PER', 1354),
#  (' Langdon', 'PER', 1355),
#  (' Neveu', 'PER', 1355),
#  (' DCPJ', 'ORG', 1355),
#  (' Cryptology Department', 'ORG', 1355),
#  (' Anglo-Franco', 'MISC', 1356),
#  (' Langdon', 'PER', 1358),
#  (' Fache', 'PER', 1360),
#  (' Fache', 'PER', 1362),
#  (' Sophie', 'PER', 1364),
#  (' English', 'MISC', 1364),
#  (' Langdon', 'PER', 1364),
#  (' Fache', 'PER', 1366),
#  (' Langdon', 'PER', 1367),
#  (' Langdon', 'PER', 1369),
#  (' Fache', 'PER', 1371),
#  (' Sophie', 'PER', 1372),
#  (' Langdon', 'PER', 1372),
#  ...]

# %%
def find_closest_loc(tag, index):
    # finds closest location to index
    curr_loc = ''
    dist = sys.maxsize
    for i in range(len(tag)):
        if bert_tags[i][1] == "LOC":
            if abs(bert_tags[i][2]-index) < dist:
                dist = abs(bert_tags[i][2]-index)
                curr_loc = bert_tags[i][0]
    return curr_loc

# %%
# go through bert_tags and map person to location based on closest distance index
pers_loc_temp = []
for i in tqdm(range(len(bert_tags))):
    if bert_tags[i][1] == "PER":
        loc = find_closest_loc(bert_tags, bert_tags[i][2])
        pers_loc_temp.append([bert_tags[i][0], loc])

pers_loc = []
# remove duplicates in pers_loc if index follows directly
for i in range(len(pers_loc_temp)-1):
    if not(pers_loc_temp[i][0] == pers_loc_temp[i+1][0] and pers_loc_temp[i][1] == pers_loc_temp[i+1][1]):
        pers_loc.append(pers_loc_temp[i])
pers_loc[:5]
# Out:
# 100%|██████████| 9823/9823 [00:03<00:00, 2627.91it/s]
# [[' Dan Brown', ' Louvre Museum'],
#  [' Jacques Sauniere', ' Louvre Museum'],
#  [' Caravaggio', ' Louvre Museum'],
#  [' Sauniere', ' Louvre Museum'],
#  [' senechaux', ' Louvre Museum']]

# %%
vectorizer = TfidfVectorizer()


def compute_similarity(a, b):
  tfidf = vectorizer.fit_transform([a, b])
  similarity = ((tfidf * tfidf.T).toarray())[0,1]
  return similarity

from functools import lru_cache

def lev_dist(a, b):
    @lru_cache(None)  # for memorization
    def min_dist(s1, s2):

        if s1 == len(a) or s2 == len(b):
            return len(a) - s1 + len(b) - s2

        # no change required
        if a[s1] == b[s2]:
            return min_dist(s1 + 1, s2 + 1)

        return 1 + min(
            min_dist(s1, s2 + 1),      # insert character
            min_dist(s1 + 1, s2),      # delete character
            min_dist(s1 + 1, s2 + 1),  # replace character
        )

    return min_dist(0, 0)

# %%
characters = ["Jacques Saunière", "Manuel Aringarosa", "Sister Sandrine Bieil", "Marie Chauvel", "Jerome Collet", "Simon Edwards", "Bezu Fache", "Jonas Faukman", "Pamela Gettum", "Claude Grouard", "Robert Langdon", "Rémy Legaludec", "Sophie Neveu"]

# %%
compute_similarity("Langdon", "robert langdon")
# Out:
# 0.5797386715376657

# %%
lev_dist("robert langdon", "robert langdon")
# Out:
# 0

# %% [markdown]
# Using Levenshtein distance

# %%
unique_chars = set()
threshold = 5
printed = []
# Compute the similarity between the characters and the persons
for i in range(len(pers_loc)):
  for j in range(len(characters)):
    temp = []
    char1 = pers_loc[i][0].lower()
    char2 = characters[j].lower()
    distance = lev_dist(char1, char2)
    if distance < threshold:
      unique_chars.add(char2)
      pers_loc[i][0] = char2
      if char1 not in printed:
        print(char1, '---' ,char2, " with similarity of {:.2f}".format(distance))
        printed.append(char1)
      break
unique_chars
# Out:
#  jacques sauniere --- jacques saunière  with similarity of 2.00
# robert langdon --- robert langdon  with similarity of 0.00
# jerome collet --- jerome collet  with similarity of 0.00
# bezu fache --- bezu fache  with similarity of 0.00
# manuel aringarosa --- manuel aringarosa  with similarity of 0.00
# jacques sauniere --- jacques saunière  with similarity of 1.00
# sister sandrine bieil --- sister sandrine bieil  with similarity of 0.00
# sophie neveu --- sophie neveu  with similarity of 0.00
# claude grouard --- claude grouard  with similarity of 0.00
# jonas faukman --- jonas faukman  with similarity of 0.00
# jacques saunière --- jacques saunière  with similarity of 0.00
#  remy legaludec --- rémy legaludec  with similarity of 2.00
# marie chauvel --- marie chauvel  with similarity of 0.00
# simon edwards --- simon edwards  with similarity of 0.00
# rémy legaludec --- rémy legaludec  with similarity of 0.00
# pamela gettum --- pamela gettum  with similarity of 0.00
# {'bezu fache',
#  'claude grouard',
#  'jacques saunière',
#  'jerome collet',
#  'jonas faukman',
#  'manuel aringarosa',
#  'marie chauvel',
#  'pamela gettum',
#  'robert langdon',
#  'rémy legaludec',
#  'simon edwards',
#  'sister sandrine bieil',
#  'sophie neveu'}

# %% [markdown]
# Using soft tf-idf

# %%
unique_chars = set()
threshold = 0.35
printed = []
# Compute the similarity between the characters and the persons
for i in range(len(pers_loc)):
  for j in range(len(characters)):
    temp = []
    char1 = pers_loc[i][0].lower()
    char2 = characters[j].lower()
    distance = compute_similarity(char1, char2)
    if distance > threshold:
      unique_chars.add(char2)
      pers_loc[i][0] = char2
      if char1 not in printed:
        print(char1, '---' ,char2, " with similarity of {:.2f}".format(distance))
        printed.append(char1)
      break
unique_chars
# Out:
# jacques saunière --- jacques saunière  with similarity of 1.00
# robert langdon --- robert langdon  with similarity of 1.00
# jerome collet --- jerome collet  with similarity of 1.00
# bezu fache --- bezu fache  with similarity of 1.00
# manuel aringarosa --- manuel aringarosa  with similarity of 1.00
# sister sandrine bieil --- sister sandrine bieil  with similarity of 1.00
# sophie neveu --- sophie neveu  with similarity of 1.00
# claude grouard --- claude grouard  with similarity of 1.00
# jonas faukman --- jonas faukman  with similarity of 1.00
# rémy legaludec --- rémy legaludec  with similarity of 1.00
# marie chauvel --- marie chauvel  with similarity of 1.00
# simon edwards --- simon edwards  with similarity of 1.00

# %%
# pers_loc_Tmp = pers_loc[:15]
# pers_loc_Tmp.append([' Sauniere', ' Grand Gallery'])
pers_loc
# Out:
# [[' Dan Brown', ' Louvre Museum'],
#  ['jacques saunière', ' Louvre Museum'],
#  [' Caravaggio', ' Louvre Museum'],
#  [' Sauniere', ' Louvre Museum'],
#  [' senechaux', ' Louvre Museum'],
#  [' Sauniere', ' Grand Gallery'],
#  ['jacques saunière', ' Grand Gallery'],
#  ['robert langdon', ' Grand Gallery'],
#  ['robert langdon', ' HOTEL RITZ PARIS'],
#  ['robert langdon', ' Chartres Cathedral'],
#  ['robert langdon', ' Vatican'],
#  ['robert langdon', ' Paris'],
#  ['robert langdon', ' CITY OF LIGHTS'],
#  ['robert langdon', ' Pavilion Dauphine'],
#  ['robert langdon', ' Vatican'],
#  ['Harrison Ford', ' Vatican'],
#  [' Monique', ' Vatican'],
#  ['robert langdon', ' Louvre'],
#  ['jerome collet', ' Louvre'],
#  ['jacques saunière', ' Louvre'],
#  [' Sauniere', ' Louvre'],
#  ['robert langdon', ' Vatican City'],
#  ['robert langdon', ' Rue La Bruyere'],
#  [' Sauniere', ' Rue La Bruyere'],
#  [' Silas', ' Rue La Bruyere'],
#  [' Silas', ' New York City'],
#  [' senechaux', ' New York City'],
#  [' Silas', ' keystone'],
#  [' Silas', 'Paris'],
#  [' Silas', ' Paris'],
#  [' God', ' Paris'],
#  [' Teacher', ' Paris'],
#  [' Silas', ' Opera House'],
#  [' Christ', ' Opera House'],
#  [' Josemaria Escriva', ' Opera House'],
#  [' Teacher', ' Opera House'],
#  [' Escriva', ' Opera House'],
#  ['robert langdon', ' Opera House'],
#  ['jacques saunière', ' Opera House'],
#  [' Sauniere', ' Opera House'],
#  [' Poussin', ' Opera House'],
#  [' Teniers', ' Opera House'],
#  ['robert langdon', ' Paris'],
#  ['jacques saunière', ' Paris'],
#  ['robert langdon', ' Europe'],
#  ['robert langdon', ' Ritz'],
#  ['robert langdon', ' Eiffel Tower'],
#  [' Vittoria', ' Eiffel Tower'],
#  [' Vittoria', ' Rome'],
#  ['robert langdon', ' Rome'],
#  ['robert langdon', ' Eiffel Tower'],
#  ['robert langdon', ' France'],
#  [' Napoleon', ' France'],
#  [' Pepin the Short', ' France'],
#  ['robert langdon', ' Tuileries'],
#  [' Claude Monet', ' Tuileries'],
#  ['robert langdon', ' Tuileries Gardens'],
#  ['robert langdon', ' Seine'],
#  ['robert langdon', ' Ramses'],
#  ['robert langdon', ' Musee du Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['robert langdon', 'Louvre'],
#  [' Art Buchwald', 'Louvre'],
#  ['robert langdon', ' Louvre'],
#  [' I. M. Pei', ' Paris Louvre'],
#  ['.', ' Paris Louvre'],
#  [' Goethe', ' Louvre'],
#  [' Pei', ' Louvre'],
#  ['Mitterrand', ' Paris'],
#  ['robert langdon', ' Paris'],
#  ['Pharaoh', ' Paris'],
#  [' Francois Mitterrand', ' Paris'],
#  [' Sphinx', ' Paris'],
#  ['robert langdon', ' F'],
#  [' le Taureau', ' F'],
#  [' Bull', ' F'],
#  [' Sphinx', ' F'],
#  [' Salvador Dali', ' F'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  ['jacques saunière', ' Louvre'],
#  [' Sauniere', ' Louvre'],
#  ['bezu fache', ' Paris'],
#  ['robert langdon', ' Paris'],
#  [' Mitterrand', ' Paris'],
#  [' Satan', ' Paris'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  ['bezu fache', ' DENON'],
#  ['robert langdon', ' DENON'],
#  [' Sauniere', ' Paris'],
#  ['robert langdon', ' Paris'],
#  ['bezu fache', ' Paris'],
#  ['jacques saunière', ' Paris'],
#  ['robert langdon', ' Denon Wing'],
#  [' Sauniere', ' Denon Wing'],
#  ['bezu fache', ' Denon Wing'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  [' Sauniere', ' Louvre'],
#  ['jacques saunière', ' Louvre'],
#  [' Horus', ' Louvre'],
#  [' Isis', ' Louvre'],
#  ['robert langdon', ' Denon Wing'],
#  ['bezu fache', ' Denon Wing'],
#  [' Sauniere', ' Denon Wing'],
#  ['robert langdon', ' France'],
#  ['bezu fache', ' France'],
#  [' Christ', ' France'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  [' Sauniere', ' Louvre'],
#  [' Entendu', ' Louvre'],
#  ['robert langdon', ' Grand Gallery'],
#  [' Sauniere', ' Grand Gallery'],
#  ['bezu fache', ' Grand Gallery'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  ['robert langdon', ' Murray Hill Place'],
#  ['manuel aringarosa', ' Lexington Avenue'],
#  ['manuel aringarosa', ' Rome'],
#  ['manuel aringarosa', ' Spain'],
#  ['God', ' Spain'],
#  [' Josemaria Escriva', ' Spain'],
#  [' God', ' Spain'],
#  [' Franco', ' Spain'],
#  [' Escriva', ' Spain'],
#  ['manuel aringarosa', ' Boston'],
#  [' God', ' Boston'],
#  [' Robert Hanssen', ' Boston'],
#  ['God', ' Vatican'],
#  ['manuel aringarosa', ' Vatican'],
#  ['manuel aringarosa', ' Spain'],
#  [' Aringar', ' Spain'],
#  ['manuel aringarosa', ' Portugal'],
#  ['Silas', ' Paris'],
#  ['manuel aringarosa', ' Church of Saint-Sulpice.'],
#  [' Silas', ' Church of Saint-Sulpice.'],
#  [' Jesus', ' Grand Gallery'],
#  [' Silas', ' Grand Gallery'],
#  [' Christ', ' Grand Gallery'],
#  [' God', ' Grand Gallery'],
#  ['robert langdon', ' Grand Gallery'],
#  [' Da Vincis', ' Grand Gallery'],
#  ['bezu fache', ' Grand Gallery'],
#  [' Caravaggio', ' Grand Gallery'],
#  ['robert langdon', ' Washington Monuments'],
#  ['bezu fache', ' Washington Monuments'],
#  ['robert langdon', ' Vatican Secret Archives'],
#  ['robert langdon', ' Rome'],
#  [' Vittoria', ' Java Sea'],
#  [' Vittoria Vetra', ' Rome'],
#  ['jacques saunière', ' Rome'],
#  [' Sauniere', ' Rome'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  [' Sauniere', ' Louvre'],
#  [' Sauniere', ' United States'],
#  ['robert langdon', ' United States'],
#  ['bezu fache', ' United States'],
#  [' Christ', ' United States'],
#  ['robert langdon', ' Venus'],
#  [' Sauniere', ' Venus'],
#  ['Sauniere', ' Venus'],
#  [' Venus', ' Venus'],
#  ['bezu fache', ' Venus'],
#  [' Venus', ' Earth'],
#  [' Eastern Star', ' Earth'],
#  [' Ishtar', ' Earth'],
#  [' Astarte', ' Earth'],
#  ['bezu fache', ' Earth'],
#  [' Venus', ' Venus'],
#  ['bezu fache', ' Venus'],
#  ['robert langdon', ' Hollywood'],
#  ['robert langdon', ' Church'],
#  ['bezu fache', ' Church'],
#  ['Goon', ' Vatican'],
#  ['robert langdon', ' Vatican'],
#  [' Poseidon', ' United States'],
#  [' Venus', ' United States'],
#  ['robert langdon', ' United States'],
#  ['bezu fache', ' United States'],
#  ['jacques saunière', ' Venus'],
#  ['bezu fache', ' Venus'],
#  ['robert langdon', ' Venus'],
#  [' Venus', ' Venus'],
#  ['bezu fache', ' Langdon'],
#  ['robert langdon', ' Langdon'],
#  ['Sauniere', ' Langdon'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  [' Sauniere', ' Louvre'],
#  ['sister sandrine bieil', ' Church of Saint-Sulpice'],
#  ['Soeur Sandrine', ' Eglise Saint-Sulpice.'],
#  ['sister sandrine bieil', ' Eglise Saint-Sulpice.'],
#  ['manuel aringarosa', ' Vatican'],
#  [' Pope John Paul II', ' Vatican'],
#  [' Pope', ' Vatican'],
#  ['sister sandrine bieil', ' Rome'],
#  ['manuel aringarosa', ' Rome'],
#  ['sister sandrine bieil', ' Paris'],
#  ['sister sandrine bieil', ' Saint-Sulpice'],
#  [' Eve', ' Saint-Sulpice'],
#  [' God', ' Saint-Sulpice'],
#  ['robert langdon', ' Saint-Sulpice'],
#  ['jacques saunière', ' Saint-Sulpice'],
#  ['robert langdon', ' Grand Gallery'],
#  ['bezu fache', ' Grand Gallery'],
#  [' Sauniere', ' Grand Gallery'],
#  ['robert langdon', ' B.C.'],
#  [' Draco', ' B.C.'],
#  ['bezu fache', ' B.C.'],
#  ['Sauniere', ' Paris'],
#  ['robert langdon', ' Paris'],
#  ['bezu fache', ' Paris'],
#  [' Draco', ' Paris'],
#  [' Sauniere', ' Paris'],
#  ['robert langdon', ' Vatican'],
#  [' Sauniere', ' Vatican'],
#  [' Leonardo da Vinci', ' Vatican'],
#  [' Da Vinci', ' Vatican'],
#  ['bezu fache', ' Vatican'],
#  [' God', ' Vatican'],
#  ['robert langdon', ' National Gallery'],
#  [' Leonardo', ' National Gallery'],
#  [' Da Vinci', ' National Gallery'],
#  ['bezu fache', ' National Gallery'],
#  [' Sauniere', ' National Gallery'],
#  ['bezu fache', ' Paris'],
#  [' Sauniere', ' Paris'],
#  ['robert langdon', ' Paris'],
#  ['jerome collet', ' Paris'],
#  ['jacques saunière', ' Paris'],
#  [' Bull', ' Paris'],
#  [' God', ' Paris'],
#  [' Pope', ' Paris'],
#  ['jerome collet', ' Denon Wing'],
#  ['bezu fache', ' Denon Wing'],
#  ['bezu fache', ' Grand Gallery'],
#  ['robert langdon', 'Capitaine'],
#  ['bezu fache', 'Capitaine'],
#  ['jerome collet', 'Capitaine'],
#  ['bezu fache', ' England'],
#  [' Sauniere', ' England'],
#  ['sophie neveu', ' England'],
#  ['bezu fache', ' Britain'],
#  ['sophie neveu', ' Britain'],
#  ['robert langdon', ' Britain'],
#  ['robert langdon', ' U.S.'],
#  ['bezu fache', ' U.S.'],
#  ['sophie neveu', ' U.S.'],
#  ['robert langdon', ' States'],
#  ['bezu fache', ' Paris'],
#  ['robert langdon', ' U.S.'],
#  ['bezu fache', ' U.S.'],
#  ['bezu fache', ' Paris'],
#  ['sophie neveu', ' Paris'],
#  ['robert langdon', ' Paris'],
#  ['sophie neveu', ' Mount Vesuvius'],
#  ['bezu fache', ' Mount Vesuvius'],
#  ['robert langdon', ' Mount Vesuvius'],
#  ['robert langdon', ' Church of Saint-Sulpice'],
#  ['sophie neveu', ' Church of Saint-Sulpice'],
#  [' Silas', ' Church of Saint-Sulpice'],
#  [' God', ' Church of Saint-Sulpice'],
#  [' Silas', ' Place Saint-Sulpice'],
#  [' Silas', ' Saint-Sulpice'],
#  [' Silas', ' Spain'],
#  [' palido', ' Andorra'],
#  [' Jesus', ' Madrid'],
#  ['manuel aringarosa', ' Madrid'],
#  [' Obra de Dios', ' Madrid'],
#  [' Silas', ' Mediterranean'],
#  [' God', ' Mediterranean'],
#  ['manuel aringarosa', ' Mediterranean'],
#  [' Silas', ' Paris'],
#  ['manuel aringarosa', ' Paris'],
#  [' Teacher', ' Paris'],
#  [' Silas', ' U.S.'],
#  [' Teacher', ' U.S.'],
#  ['bezu fache', ' U.S.'],
#  ['sophie neveu', ' U.S.'],
#  [' Sauniere', ' U.S.'],
#  ['jacques saunière', ' U.S.'],
#  ['robert langdon', ' U.S.'],
#  [' Leonardo Fibonacci', ' U.S.'],
#  [' Fibonacci', ' U.S.'],
#  ['bezu fache', ' Grand Gallery'],
#  ['robert langdon', ' Grand Gallery'],
#  [' Sauniere', ' Grand Gallery'],
#  ['sophie neveu', ' Grand Gallery'],
#  ['jerome collet', ' Grand Gallery'],
#  [' Renoir', ' Grand Gallery'],
#  ['robert langdon', ' Louvre'],
#  ['sophie neveu', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  ['sophie neveu', ' Paris'],
#  ['robert langdon', ' Paris'],
#  ['bezu fache', ' Paris'],
#  ['jacques saunière', ' Paris'],
#  [' Sauniere', ' Paris'],
#  ['sophie neveu', ' France'],
#  ['bezu fache', ' France'],
#  [' Sauniere', ' France'],
#  ['robert langdon', ' France'],
#  [' devil', ' France'],
#  ['jacques saunière', ' France'],
#  ['jacques saunière', ' Paris'],
#  ['bezu fache', ' Paris'],
#  ['robert langdon', ' Paris'],
#  ['sophie neveu', ' Paris'],
#  [' Sauniere', ' Paris'],
#  [' Sauniere', ' France'],
#  ['robert langdon', ' France'],
#  ['sophie neveu', ' France'],
#  [' Da Vinci', ' France'],
#  ['jacques saunière', ' France'],
#  [' I', ' France'],
#  [' Crypto', ' France'],
#  ['P.S.', ' France'],
#  ['.', ' France'],
#  ['jacques saunière', ' France'],
#  ['bezu fache', ' France'],
#  ['jerome collet', ' France'],
#  ['bezu fache', ' Place Saint-Sulpice'],
#  ['jerome collet', ' Place Saint-Sulpice'],
#  [' God', ' Place Saint-Sulpice'],
#  ['sophie neveu', ' Place Saint-Sulpice'],
#  ['robert langdon', ' Place Saint-Sulpice'],
#  [' Silas', ' Place Saint-Sulpice'],
#  [' Silas', ' France'],
#  [' God', ' France'],
#  [' Teacher', ' France'],
#  [' Dios', ' France'],
#  ['sophie neveu', ' England'],
#  ['bezu fache', ' England'],
#  ['robert langdon', ' England'],
#  ['jacques saunière', ' England'],
#  [' Sauniere', ' Paris'],
#  ['sophie neveu', ' Paris'],
#  ['sophie neveu', ' Louvre'],
#  ['jacques saunière', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['robert langdon', ' Paris'],
#  ['sophie neveu', ' Paris'],
#  ['sophie neveu', ' Denon Wing'],
#  ['robert langdon', ' Denon Wing'],
#  ['se Sophie', ' Denon Wing'],
#  ['sophie neveu', ' U.S.'],
#  ['robert langdon', ' U.S.'],
#  ['bezu fache', ' U.S.'],
#  ['sophie neveu', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  ['jerome collet', ' Louvre'],
#  ['sophie neveu', ' Grand Gallery'],
#  [' Sauniere', ' Grand Gallery'],
#  ['bezu fache', ' Grand Gallery'],
#  ['jacques saunière', ' Grand Gallery'],
#  ['jerome collet', ' Grand Gallery'],
#  ['robert langdon', ' Grand Gallery'],
#  ['Alarme', ' Grand Gallery'],
#  ['bezu fache', ' Collet'],
#  ['robert langdon', ' Collet'],
#  ['jerome collet', ' Collet'],
#  ['jerome collet', ' Paris'],
#  ['robert langdon', ' Paris'],
#  [' God', ' Place du Carrousel'],
#  ['jerome collet', ' Place du Carrousel'],
#  ['robert langdon', ' Place du Carrousel'],
#  ['bezu fache', ' Place du Carrousel'],
#  ['robert langdon', ' Paris'],
#  ['Jesuf', ' Paris'],
#  ['jerome collet', ' Paris'],
#  ['robert langdon', ' Place du Carrousel'],
#  ['bezu fache', ' Grand Gallery'],
#  ['jerome collet', ' Grand Gallery'],
#  ['jerome collet', ' Place du Carrousel'],
#  [' Jesus', ' Place du Carrousel'],
#  ['bezu fache', ' Denon Wing'],
#  [' Sauniere', ' Denon Wing'],
#  ['jerome collet', ' Denon Wing'],
#  ['robert langdon', ' Carrousel'],
#  ['bezu fache', ' Carrousel'],
#  ['jerome collet', ' Carrousel'],
#  ['robert langdon', ' Seine'],
#  ['bezu fache', ' Seine'],
#  ['jerome collet', ' Seine'],
#  ['bezu fache', ' Pont du Carrousel'],
#  ['robert langdon', ' Pont du Carrousel'],
#  ['jerome collet', ' Pont des Saints-Peres'],
#  ['bezu fache', ' Pont des Saints-Peres'],
#  ['jerome collet', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Grand Gallery'],
#  ['jerome collet', ' Grand Gallery'],
#  ['robert langdon', ' Grand Gallery'],
#  ['robert langdon', ' Louvre'],
#  ['sophie neveu', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  ['bezu fache', ' Grand Gallery'],
#  ['sophie neveu', ' Grand Gallery'],
#  ['robert langdon', ' Grand Gallery'],
#  ['sophie neveu', ' Church of Saint-Sulpice'],
#  [' Isis', ' Notre Dame'],
#  [' Marquis de Sade', ' Notre Dame'],
#  [' Baudelaire', ' Notre Dame'],
#  [' Victor Hugo', ' Notre Dame'],
#  [' Silas', ' Saint-Sulpice'],
#  [' Silas', ' Spain'],
#  ['sister sandrine bieil', ' Spain'],
#  [' Silas', ' Notre Dame'],
#  ['sister sandrine bieil', ' Notre Dame'],
#  [' Silas', ' Saint-Sulpice'],
#  [' God', ' Saint-Sulpice'],
#  ['sister sandrine bieil', ' Saint-Sulpice'],
#  [' Silas', ' Grand Gallery'],
#  ['sister sandrine bieil', ' Grand Gallery'],
#  [' God', ' Grand Gallery'],
#  ['sophie neveu', ' Grand Gallery'],
#  [' Da Vinci', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['sophie neveu', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  ['robert langdon', ' PHI'],
#  [' Sauniere', ' PHI'],
#  ['sophie neveu', ' PHI'],
#  [' Da Vinci', ' PHI'],
#  [' Stettner', ' PHI'],
#  ['Stettner', ' PHI'],
#  ['Way', ' PHI'],
#  [' Leonardo da Vinci', ' PHI'],
#  [' Marcus Vitruvius', ' PHI'],
#  [' Da Vinci', ' PHI. PHI. PHI.'],
#  ['robert langdon', ' PHI. PHI. PHI.'],
#  [' God', ' PHI. PHI. PHI.'],
#  ['robert langdon', ' Parthenon'],
#  [' Michelangelo', ' Parthenon'],
#  [' Albrecht Diirer', ' Parthenon'],
#  [' Da Vinci', ' Parthenon'],
#  [' Mozart', ' Parthenon'],
#  [' Beethoven', ' Parthenon'],
#  [' Bartok', ' Parthenon'],
#  [' Debussy', ' Parthenon'],
#  [' Schubert', ' Parthenon'],
#  [' Stradivarius', ' Parthenon'],
#  [' Stettner', ' Parthenon'],
#  [' Leonardo', ' Parthenon'],
#  [' Jesus', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['sophie neveu', ' Louvre'],
#  [' PHI', ' Louvre'],
#  [' Da Vinci', ' Louvre'],
#  [' Sauniere', ' Louvre'],
#  [' devil', ' Louvre'],
#  [' Leonardo da Vinci', ' Louvre'],
#  [' Picasso', ' Louvre'],
#  [' Leonardo da Vinci', ' Salle des Etats'],
#  ['sophie neveu', ' Salle des Etats'],
#  ['sophie neveu', ' Mona Lisa'],
#  ['robert langdon', ' Denon Wing'],
#  ['sophie neveu', ' Denon Wing'],
#  [' Da Vinci', ' Denon Wing'],
#  ['sophie neveu', ' Salle des Etats'],
#  [' Mona Lisa', ' Salle des Etats'],
#  [' Sauniere', ' Salle des Etats'],
#  [' brumeux', ' Salle des Etats'],
#  ['Foggy', ' Salle des Etats'],
#  ['sophie neveu', ' Mona Lisa'],
#  [' Mona Lisa', ' Mona Lisa'],
#  ['robert langdon', ' Mona Lisa'],
#  ['robert langdon', ' Grand Gallery'],
#  ['bezu fache', ' Grand Gallery'],
#  ['sophie neveu', ' Grand Gallery'],
#  ['robert langdon', ' Cambridge'],
#  ['sophie neveu', ' Cambridge'],
#  [' Sauniere', ' Mona Lisa'],
#  ['robert langdon', ' Mona Lisa'],
#  ['sophie neveu', ' Mona Lisa'],
#  ['robert langdon', ' Wheeling'],
#  [' Sauniere', ' Wheeling'],
#  ['jacques saunière', ' Wheeling'],
#  ['robert langdon', ' Saint- Sulpice'],
#  [' Silas', ' Saint- Sulpice'],
#  [' Saint-Sulpice', ' Saint- Sulpice'],
#  [' Silas', ' Saint-Sulpice'],
#  [' Silas', ' Rose Line'],
#  [' Silas', ' Priory'],
#  [' Teacher', ' Priory'],
#  [' Silas', ' Saint-Sulpice'],
#  [' Teacher', ' Saint-Sulpice'],
#  [' Silas', ' Priory'],
#  ['manuel aringarosa', ' Leonardo da Vinci International Airport'],
#  ['manuel aringarosa', ' Paris'],
#  [' God', ' Paris'],
#  ['sophie neveu', ' Salle des Etats'],
#  [' Botticelli', ' Salle des Etats'],
#  ['sophie neveu', ' Louvre'],
#  ['sophie neveu', ' Salle des Etats'],
#  ['robert langdon', ' Salle des Etats'],
#  ['bezu fache', ' Salle des Etats'],
#  [' P.S..', ' Salle des Etats'],
#  [' P.S.', ' Salle des Etats'],
#  ['.', ' Salle des Etats'],
#  [' Grand-pere', ' Salle des Etats'],
#  ['P.S', ' Salle des Etats'],
#  ['re', ' Salle des Etats'],
#  [' P', ' Salle des Etats'],
#  ['S.', ' Salle des Etats'],
#  ['robert langdon', ' France'],
#  ['sophie neveu', ' France'],
#  [' P', ' France'],
#  [' Botticelli', ' France'],
#  [' Sir Isaac Newton', ' France'],
#  [' Victor Hugo', ' France'],
#  [' Leonardo da Vinci', ' Priory'],
#  ['sophie neveu', ' Priory'],
#  ['Da Vinci', ' Priory'],
#  [' Leonardo', ' Priory'],
#  ['robert langdon', ' Priory'],
#  [' Leonardo da Vinci', ' P.S.'],
#  ['robert langdon', ' P.S.'],
#  ['robert langdon', ' Priory'],
#  ['robert langdon', ' Mona Lisa'],
#  [' Lisa', ' Mona Lisa'],
#  [' Leonardo da Vinci', ' Priory of Sion'],
#  [' Silas', ' Saint-Sulpice'],
#  [' Silas', ' Sulpice'],
#  [' Silas', ' Saint- Sulpice'],
#  ['sister sandrine bieil', ' Saint- Sulpice'],
#  ['robert langdon', 'U.S.'],
#  ['bezu fache', ' Seine'],
#  ['robert langdon', ' Seine'],
#  ['robert langdon', ' Paris'],
#  ['bezu fache', ' Paris'],
#  ['sophie neveu', ' Paris'],
#  [' Da Vinci', ' Salle des Etats'],
#  [' Mona Lisa', ' Louvre'],
#  [' La Jaconde', ' Louvre'],
#  ['robert langdon', ' Salle des Etats'],
#  ['sophie neveu', ' Salle des Etats'],
#  [' Leonardo da Vinci', ' Essex County Penitentiary'],
#  [' Da Vinci', ' Essex County Penitentiary'],
#  ['robert langdon', ' Essex County Penitentiary'],
#  [' Mona Lisa', ' Essex County Penitentiary'],
#  ['Da Vinci', ' Essex County Penitentiary'],
#  [' Hermes', ' Essex County Penitentiary'],
#  [' Aphrodite', ' Essex County Penitentiary'],
#  [' Langford', ' Essex County Penitentiary'],
#  [' Lisa', ' Essex County Penitentiary'],
#  [' Anion', ' Essex County Penitentiary'],
#  [' Amon', ' Essex County Penitentiary'],
#  ['robert langdon', ' Grand Gallery'],
#  [' Amon', ' Grand Gallery'],
#  [' Isis', ' Grand Gallery'],
#  [' Mona Lisa', ' Grand Gallery'],
#  [' Da Vinci', ' Grand Gallery'],
#  ['sophie neveu', ' Grand Gallery'],
#  ['jacques saunière', ' Grand Gallery'],
#  [' Sauniere', ' Grand Gallery'],
#  ['bezu fache', ' Grand Gallery'],
#  ['bezu fache', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['sophie neveu', ' Louvre'],
#  ['jerome collet', ' Louvre'],
#  ['robert langdon', ' Paris'],
#  ['robert langdon', ' Salle des Etats'],
#  [' Mona Lisa', ' Salle des Etats'],
#  ['robert langdon', 'The Priory'],
#  ['sophie neveu', 'The Priory'],
#  ['robert langdon', ' Priory'],
#  ['sophie neveu', ' Priory'],
#  [' Constantine', ' Priory'],
#  [' Sauniere', ' Priory'],
#  [' God', 'os'],
#  [' Eve', 'os'],
#  ['robert langdon', ' Sion'],
#  ['sophie neveu', ' Sion'],
#  ['sophie neveu', ' Louvre'],
#  ['Arretez', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['robert langdon', ' Saint-Sulpice'],
#  [' Silas', ' Saint-Sulpice'],
#  [' Silas', ' Rose Line'],
#  [' Moses', ' Rose Line'],
#  [' Job.', ' Rose Line'],
#  [' God', ' Rose Line'],
#  ['sister sandrine bieil', ' Rose Line'],
#  [' God', ' Paris'],
#  ['sister sandrine bieil', ' Paris'],
#  [' Silas', ' Paris'],
#  [' Silas', ' Mona Lisa'],
#  ['claude grouard', ' Mona Lisa'],
#  ['jacques saunière', ' Mona Lisa'],
#  [' Sauniere', ' Mona Lisa'],
#  ['robert langdon', ' Mona Lisa'],
#  ['bezu fache', ' Mona Lisa'],
#  ['claude grouard', ' Salle des Etats'],
#  ['Votre', ' Salle des Etats'],
#  ['Repondez', ' Salle des Etats'],
#  ['sophie neveu', ' Salle des Etats'],
#  [' Sauniere', ' Salle des Etats'],
#  ['robert langdon', ' Salle des Etats'],
#  [' God', ' Salle des Etats'],
#  [' Da Vinci', ' Salle des Etats'],
#  [' Virgin Mary', ' Salle des Etats'],
#  [' Jesus', ' Salle des Etats'],
#  [' John', ' Salle des Etats'],
#  [' Baptist', ' Salle des Etats'],
#  [' Uriel', ' Salle des Etats'],
#  ['sophie neveu', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  [' Static.', ' Louvre'],
#  [' Leonardo da Vinci', ' Louvre'],
#  ['claude grouard', ' Louvre'],
#  [' Virgin Mary', ' Louvre'],
#  [' Jesus', ' Louvre'],
#  [' John the Baptist', ' Louvre'],
#  [' Da Vinci', ' Louvre'],
#  [' Madonna of the Rocks', ' Louvre'],
#  [' Mona Lisa', ' Louvre'],
#  ['Madonna of the Rocks', ' Louvre'],
#  [' Madonna of the Rocks', ' Saint-Sulpice'],
#  ['robert langdon', ' Saint-Sulpice'],
#  ['sister sandrine bieil', ' Saint-Sulpice'],
#  ['sister sandrine bieil', ' Denon Wing'],
#  ['Jesus', ' Denon Wing'],
#  ['robert langdon', ' Denon Wing'],
#  ['sophie neveu', ' Denon Wing'],
#  ['robert langdon', ' Carrousel du Louvre'],
#  ['sophie neveu', ' Carrousel du Louvre'],
#  ['sophie neveu', ' Rue de Rivoli'],
#  ['robert langdon', ' Rue de Rivoli'],
#  ['sophie neveu', ' Louvre'],
#  ['sophie neveu', ' Rivoli'],
#  ['robert langdon', ' Rivoli'],
#  ['robert langdon', ' Louvre'],
#  ['sophie neveu', ' Champs- Elysees'],
#  ['robert langdon', ' Champs- Elysees'],
#  [' Madonna of', ' Madonna of the Rocks'],
#  ['sophie neveu', ' Madonna of the Rocks'],
#  ['robert langdon', ' Madonna of the Rocks'],
#  [' Sauniere', ' Madonna of the Rocks'],
#  [' Leonardo da Vinci', ' Madonna of the Rocks'],
#  [' Da Vinci', ' Madonna of the Rocks'],
#  [' Leonardo', ' Madonna of the Rocks'],
#  [' Virgin Mary', ' Madonna of the Rocks'],
#  [' John the Baptist', ' Madonna of the Rocks'],
#  [' Uriel', ' Madonna of the Rocks'],
#  [' Jesus', ' Madonna of the Rocks'],
#  [' Baby Jesus', ' Madonna of the Rocks'],
#  [' Mary', ' Madonna of the Rocks'],
#  ['John', ' Madonna of the Rocks'],
#  [' John', ' Madonna of the Rocks'],
#  [' Jesus', ' London'],
#  [' Mary', ' London'],
#  [' John', ' London'],
#  [' Uriel', ' London'],
#  ['robert langdon', ' London'],
#  [' Da Vinci', ' London'],
#  ['sophie neveu', ' Champs-Elysees'],
#  ['robert langdon', ' Champs-Elysees'],
#  ['robert langdon', ' Hotel de Crillon'],
#  ['sophie neveu', ' Hotel de Crillon'],
#  [' P.S', ' Hotel de Crillon'],
#  ['.', ' Hotel de Crillon'],
#  [' P', ' Hotel de Crillon'],
#  ['S', ' Hotel de Crillon'],
#  ['sophie neveu', ' Charles de Gaulle Airport'],
#  [' Grand-pere', ' Charles de Gaulle Airport'],
#  ['sophie neveu', ' Britain'],
#  ['sophie neveu', ' Louvre'],
#  ['jacques saunière', ' Normandy'],
#  ['sophie neveu', ' London'],
#  ['sophie neveu', ' Creully'],
#  ['sophie neveu', ' Paris'],
#  ['jacques saunière', ' Paris'],
#  ['sophie neveu', ' Normandy'],
#  [' Aubusson', ' Normandy'],
#  ['sophie neveu', ' Paris'],
#  ['robert langdon', ' Paris'],
#  ['sophie neveu', ' Avenue Gabriel'],
#  ['robert langdon', ' Avenue Gabriel'],
#  ['sophie neveu', ' Champs-Elysees'],
#  ['robert langdon', ' Champs-Elysees'],
#  ['robert langdon', ' Madonna of'],
#  ['sophie neveu', ' Madonna of'],
#  ['robert langdon', ' Priory of Sion'],
#  [' P.S.', ' Priory of Sion'],
#  ['sophie neveu', ' Priory of Sion'],
#  ['robert langdon', ' Priory'],
#  ['jacques saunière', ' Priory'],
#  ['sophie neveu', ' Priory'],
#  ['sophie neveu', ' Ritz'],
#  ['robert langdon', ' Ritz'],
#  ['bezu fache', ' Ritz'],
#  ['bezu fache', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['sophie neveu', ' Louvre'],
#  ['bezu fache', ' Champs-Ely sees'],
#  ['robert langdon', ' Champs-Ely sees'],
#  ['sophie neveu', ' Champs-Elysees'],
#  ['robert langdon', ' Champs-Elysees'],
#  [' Napoleon', ' Champs-Elysees'],
#  [' Mickey Mouse', ' Boulevard Malesherbes'],
#  ['robert langdon', ' Boulevard Malesherbes'],
#  [' Mickey', ' Boulevard Malesherbes'],
#  ['sophie neveu', ' Boulevard Malesherbes'],
#  ['sophie neveu', ' Gare Saint-Lazare'],
#  ['robert langdon', ' Gare Saint-Lazare'],
#  ['robert langdon', ' Paris'],
#  ['sophie neveu', ' Paris'],
#  ['robert langdon', ' U.S.'],
#  ['manuel aringarosa', ' Leonardo da Vinci International Airport'],
#  ['manuel aringarosa', ' Vatican'],
#  [' Jesus Christ', ' Europe'],
#  ['manuel aringarosa', ' Castel Gandolfo'],
#  ['manuel aringarosa', ' Vatican'],
#  [' Pope', ' Vatican'],
#  [' God', ' Vatican'],
#  ['manuel aringarosa', ' Vatican City'],
#  [' Pope', ' Castel Gandolfo'],
#  [' Pope', ' Spe'],
#  ['manuel aringarosa', ' Vatican'],
#  [' Gandolfo', ' Castel Gandolfo'],
#  [' Curiazi', ' Rome'],
#  [' Mangano', ' Vatican'],
#  [' Copernicus', ' Vatican'],
#  [' Galileo', ' Vatican'],
#  [' Kepler', ' Vatican'],
#  [' Newton', ' Vatican'],
#  [' Secchi', ' Vatican'],
#  ['manuel aringarosa', ' Vatican City'],
#  [' God', ' Vatican City'],
#  [' Silas', ' Gare Saint-Lazare'],
#  ['sophie neveu', ' Gare Saint-Lazare'],
#  ['robert langdon', ' LYON'],
#  ['sophie neveu', ' LYON'],
#  ['robert langdon', ' Lyon'],
#  ['sophie neveu', ' Lyon'],
#  ['robert langdon', ' Rue de Clichy'],
#  ['sophie neveu', ' Rue de Clichy'],
#  ['robert langdon', ' Montmartre'],
#  ['sophie neveu', ' Montmartre'],
#  ['sophie neveu', ' Priory'],
#  ['robert langdon', ' Priory'],
#  ['robert langdon', ' Rue Haxo'],
#  ['sophie neveu', ' Rue Haxo'],
#  ['sophie neveu', ' Paris'],
#  ['sophie neveu', ' Bois de Boulogne'],
#  ['sophie neveu', ' Rue Haxo'],
#  ['robert langdon', ' Priory'],
#  ['bezu fache', ' Salle des Etats'],
#  ['claude grouard', ' Salle des Etats'],
#  ['sophie neveu', ' Salle des Etats'],
#  ['robert langdon', ' Salle des Etats'],
#  ['jerome collet', ' Salle des Etats'],
#  ['jerome collet', ' Paris'],
#  ['bezu fache', ' Paris'],
#  ['robert langdon', ' Paris'],
#  ['sophie neveu', ' Paris'],
#  ['Field.', ' Bois de Boulogne'],
#  ['jerome collet', ' Bois de Boulogne'],
#  ['bezu fache', ' Bois de Boulogne'],
#  [' Bosch', ' Bois de Boulogne'],
#  ['robert langdon', ' Priory of Sion'],
#  ['sophie neveu', ' Priory of Sion'],
#  ['robert langdon', ' Heaven'],
#  ['robert langdon', ' Priory of Sion'],
#  [' Pope', ' Priory of Sion'],
#  [' Godefroi de Bouillon', ' Priory of Sion'],
#  [' Godefroi', ' Priory of Sion'],
#  [' Christ', ' Priory of Sion'],
#  [' Herod', ' Jerusalem'],
#  [' Godefroi', ' Jerusalem'],
#  ['sophie neveu', ' Priory'],
#  ['robert langdon', ' Priory'],
#  ['robert langdon', ' Sion'],
#  ['sophie neveu', ' Sion'],
#  ['robert langdon', ' Holy Land'],
#  ['sophie neveu', ' Holy Land'],
#  [' Baldwin II', ' Holy Land'],
#  [' Baldwin', ' Holy Land'],
#  ['robert langdon', ' Pri'],
#  [' God', ' Pri'],
#  ['sophie neveu', ' Pri'],
#  ['robert langdon', ' Europe'],
#  [' Pope Innocent II', ' Vatican'],
#  [' Pope Clement V', ' Vatican'],
#  [' Philippe IV', ' France'],
#  [' Pope', ' France'],
#  [' Pope Clement', ' Europe'],
#  [' Clement', ' Europe'],
#  [' God', ' Europe'],
#  ['sophie neveu', ' Vatican'],
#  [' Clement', ' Vatican'],
#  ['robert langdon', ' Priory of Sion'],
#  ['sophie neveu', ' United Kingdom'],
#  ['robert langdon', ' United Kingdom'],
#  [' Sangreal', ' Sangreal'],
#  ['robert langdon', ' Sangreal'],
#  ['sophie neveu', ' Sangreal'],
#  ['robert langdon', ' Paris'],
#  ['sophie neveu', 'Holy Grail'],
#  ['robert langdon', 'Holy Grail'],
#  ['robert langdon', ' Holy Grail'],
#  ['sophie neveu', ' Holy Grail'],
#  ['sophie neveu', ' Grail'],
#  [' Jesus', ' Grail'],
#  [' Joseph', ' Grail'],
#  ['sophie neveu', ' Priory of Sion'],
#  ['robert langdon', ' Priory of Sion'],
#  ['sophie neveu', ' Holy Grail'],
#  ['robert langdon', ' Holy Grail'],
#  ['jonas faukman', ' New York'],
#  ['robert langdon', ' New York'],
#  ['jonas faukman', ' Holy Grail'],
#  ['robert langdon', ' Holy Grail'],
#  [' Leigh Teabing', ' Holy Grail'],
#  ['Teabing', ' Holy Grail'],
#  [' Harry Potter', ' Holy Grail'],
#  ['Laissez-le', ' Holy Grail'],
#  ['Arretez', ' Holy Grail'],
#  ['Descendez', ' Holy Grail'],
#  ['sophie neveu', ' Rue La Bruyere'],
#  ['robert langdon', ' Rue La Bruyere'],
#  ['ment', ' Rue La Bruyere'],
#  [' Silas', ' Rue La Bruyere'],
#  [' Silas', ' Saint-Sulpice'],
#  [' God', ' Saint-Sulpice'],
#  ['manuel aringarosa', ' Saint-Sulpice'],
#  [' Silas', ' Op'],
#  ['manuel aringarosa', ' Op'],
#  [' Silas', ' New York City'],
#  ['manuel aringarosa', ' New York City'],
#  [' Silas', ' Spain'],
#  ['manuel aringarosa', ' Spain'],
#  [' Noah', ' Ark'],
#  ['Noah', ' Ark'],
#  [' Silas', ' Ark'],
#  ['manuel aringarosa', ' Ark.'],
#  [' Noah', ' Ark.'],
#  [' Silas', ' Ark.'],
#  [' Lord', ' Ark.'],
#  [' White.', ' Bois de Boulogne'],
#  [' Silas', ' Bois de Boulogne'],
#  ['robert langdon', ' Bois de Boulogne'],
#  [' Repondez', ' Bois de Boulogne'],
#  ['robert langdon', ' Allee de Longchamp'],
#  ['sophie neveu', ' Allee de Longchamp'],
#  ['robert langdon', ' Rue Haxo'],
#  ['sophie neveu', ' Rue Haxo'],
#  ['sophie neveu', ' Roland Garros'],
#  ['robert langdon', ' Roland Garros'],
#  ['sophie neveu', ' Priory'],
#  ['robert langdon', ' Priory'],
#  ['robert langdon', ' England'],
#  [' Da Vinci', ' England'],
#  [' Arthur', ' Great Britain'],
#  [' Leonardo', ' Great Britain'],
#  [' Da Vinci', ' Grail'],
#  ['a', ' Isis'],
#  [' Da Vinci', ' Isis'],
#  ['robert langdon', ' Holy Grail'],
#  [' Da Vinci', ' Holy Grail'],
#  [' Maurizio Seracini', ' Holy Grail'],
#  [' Leonardo', ' Holy Grail'],
#  [' Seracini', ' Holy Grail'],
#  [' Da Vinci', ' Florence'],
#  [' Leonardo da Vinci', ' Leonardo Room'],
#  [' Da Vinci', ' Grail'],
#  [' Mona Lisa', ' Grail'],
#  ['sophie neveu', ' Grail'],
#  ['robert langdon', ' Grail'],
#  ['robert langdon', ' Priory of Sion'],
#  ['sophie neveu', ' Priory'],
#  ['sophie neveu', ' Normandy'],
#  ['robert langdon', ' Normandy'],
#  ['robert langdon', ' Roland Garros'],
#  ['sophie neveu', ' Roland Garros'],
#  ['robert langdon', ' Rue Haxo'],
#  ['sophie neveu', ' Rue Haxo'],
#  ['robert langdon', ' Switzerland'],
#  ['sophie neveu', ' Switzerland'],
#  ['sophie neveu', ' Castel Gandolfo'],
#  ['robert langdon', ' Castel Gandolfo'],
#  ['manuel aringarosa', ' Castel Gandolfo'],
#  ['manuel aringarosa', ' Vatican City'],
#  ['manuel aringarosa', ' Vatican'],
#  [' God', ' Vatican'],
#  ['manuel aringarosa', ' Vatican City'],
#  ['manuel aringarosa', 'Paris'],
#  ['sophie neveu', ' Zurich'],
#  ['robert langdon', ' Zurich'],
#  ['sophie neveu', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['robert langdon', 'Bonsoir'],
#  ['sophie neveu', 'Bonsoir'],
#  [' Vernet', 'Bonsoir'],
#  ['sophie neveu', ' Gare du Nord'],
#  ['jerome collet', ' Gare du Nord'],
#  ['bezu fache', ' Gare du Nord'],
#  ['robert langdon', ' Paris'],
#  ['sophie neveu', ' Paris'],
#  [' Sauniere', ' Paris'],
#  ['bezu fache', ' Paris'],
#  ['jerome collet', ' Rue Haxo'],
#  [' Andre Vernet', ' Paris'],
#  [' Vernet', ' Quartier Latin'],
#  [' Fragonard', ' Quartier Latin'],
#  [' Boucher', ' Quartier Latin'],
#  [' Andre Vernet', ' Quartier Latin'],
#  ['sophie neveu', ' Quartier Latin'],
#  ['sophie neveu', ' Louvre'],
#  ['jacques saunière', ' Louvre'],
#  [' Andre Vernet', ' Louvre'],
#  ['jacques saunière', ' Louvre'],
#  [' Vernet', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  ['bezu fache', ' Louvre'],
#  ['sophie neveu', ' Priory'],
#  [' Vernet', ' Priory'],
#  ['sophie neveu', ' Louvre'],
#  [' Madonna of the Rocks', ' Louvre'],
#  [' Vernet', ' Louvre'],
#  ['sophie neveu', ' Priory of Sion'],
#  ['robert langdon', ' Priory of Sion'],
#  [' Vernet', ' Priory of Sion'],
#  [' Sangreal', ' Priory of Sion'],
#  ['sophie neveu', ' Louvre'],
#  [' Vernet', ' Louvre'],
#  ['robert langdon', ' Louvre'],
#  [' Grand-pere', ' Louvre'],
#  [' Sauniere', ' Louvre'],
#  ['robert langdon', ' Rosewood'],
#  ['sophie neveu', ' Rosewood'],
#  ['robert langdon', ' Priory'],
#  ['sophie neveu', ' Priory'],
#  [' Andre Vernet', ' Priory'],
#  [' Vernet', ' Priory'],
#  [' God', ' Priory'],
#  [' Sauniere', ' Priory'],
#  [' Vernet', ' St. Thurial'],
#  ['sophie neveu', ' St. Thurial'],
#  ['robert langdon', ' St. Thurial'],
#  ['jerome collet', ' St. Thurial'],
#  [' Vernet', ' St. Germain des Pres.'],
#  [' Silas', ' Vatican Observatory'],
#  ['manuel aringarosa', ' Vatican Observatory'],
#  [' Silas', ' The Way'],
#  [' God', ' The Way'],
#  ['manuel aringarosa', ' The Way'],
#  ['Silas', ' The Way'],
#  ['God', ' The Way'],
#  [' Teacher', ' The Way'],
#  ['jacques saunière', ' The Way'],
#  ['robert langdon', ' The Way'],
#  [' Vernet', ' The Way'],
#  ['sophie neveu', ' The Way'],
#  ['sophie neveu', ' clo'],
#  ['robert langdon', ' clo'],
#  [' Leonardo da Vinci', ' clo'],
#  ['Da Vinci', ' clo'],
#  [' Da Vinci', ' clo'],
#  ['jacques saunière', ' clo'],
#  [' Faberge', ' clo'],
#  [' Leonardo', ' clo'],
#  [' Zimmerman', ' clo'],
#  [' Schneier', ' clo'],
#  [' Julius Caesar', ' clo'],
#  [' Mary', ' clo'],
#  [' Queen of Scots', ' clo'],
#  [' Abu Yusuf Ismail al-Kindi', ' clo'],
#  ['robert langdon', ' Grail'],
#  ['sophie neveu', ' Grail'],
#  [' Da Vinci', ' Grail'],
#  ['Papyrus.', ' Grail'],
#  ['Vinegar', ' Grail'],
#  ['sophie neveu', ' Priory'],
#  ['robert langdon', ' Priory'],
#  [' Venus', ' Priory'],
#  [' Rose', ' Priory'],
#  [' Voiite', ' Priory'],
#  ['robert langdon', ' Keystones'],
#  ['sophie neveu', ' Keystones'],
#  ['robert langdon', ' Priory'],
#  ['sophie neveu', ' Holy Grail'],
#  ['sophie neveu', ' Priory'],
#  ['sophie neveu', ' Holy Grail'],
#  ['robert langdon', ' Holy Grail'],
#  [' Leonardo da Vinci', ' Priory of Sion'],
#  [' Master', ' Priory of Sion'],
#  [' Rosette', ' Holy Grail'],
#  ['robert langdon', ' Priory'],
#  ['sophie neveu', ' Priory'],
#  ['robert langdon', ' Holy Grail'],
#  ['sophie neveu', ' Holy Grail'],
#  ['sophie neveu', ' Priory'],
#  ['robert langdon', ' Priory'],
#  ...]

# %%
def tmpMethod(pers_loc_Tmp):
    i = 0
    while(i < len(pers_loc_Tmp)):
        j = i+1
        while(j<len(pers_loc_Tmp)):
            if pers_loc_Tmp[i][0] == pers_loc_Tmp[j][0] and pers_loc_Tmp[i][1] == pers_loc_Tmp[j][1]:
                del pers_loc_Tmp[j]
                j = i+1
                continue
            elif pers_loc_Tmp[i][0] == pers_loc_Tmp[j][0] and pers_loc_Tmp[i][1] != pers_loc_Tmp[j][1]:
                break
            j+=1
        i+=1
    return pers_loc_Tmp

tmpMethod(pers_loc);

# %%
pers_loc[:10]
# Out:
# [[' Dan Brown', ' Louvre Museum'],
#  ['jacques saunière', ' Louvre Museum'],
#  [' Caravaggio', ' Louvre Museum'],
#  [' Sauniere', ' Louvre Museum'],
#  [' senechaux', ' Louvre Museum'],
#  [' Sauniere', ' Grand Gallery'],
#  ['jacques saunière', ' Grand Gallery'],
#  ['robert langdon', ' Grand Gallery'],
#  ['robert langdon', ' HOTEL RITZ PARIS'],
#  ['robert langdon', ' Chartres Cathedral']]

# %%
# only print pers_loc when robert langdon is in subindex 0
loc_robert = [x for x in pers_loc if x[0] == 'robert langdon']
loc_robert[:10]
# Out:
# [['robert langdon', ' Grand Gallery'],
#  ['robert langdon', ' HOTEL RITZ PARIS'],
#  ['robert langdon', ' Chartres Cathedral'],
#  ['robert langdon', ' Vatican'],
#  ['robert langdon', ' Paris'],
#  ['robert langdon', ' CITY OF LIGHTS'],
#  ['robert langdon', ' Pavilion Dauphine'],
#  ['robert langdon', ' Vatican'],
#  ['robert langdon', ' Louvre'],
#  ['robert langdon', ' Vatican City']]

# %%
len(loc_robert)
# Out:
# 561
